# %%
import numpy as np
import pandas as pd
from pandas import *
import os

# %% [raw]
# What I want to do is open up the data from visignsys into pandas, display the data in rows and collums.
# Dates with comments along side. The best way to do this is save dicts to files and open them with pandas, creating r n c.

# %%
readjson = open('/home/wcmckee/visignsys/index.meta', 'r')

# %%
checkj = readjson.read()

# %%
s = Series(checkj)

# %%
s
# Out:
# "['ESW', 'sunny day. going for walk.', '15:14', 'William Mckee', '12-Nov-2014']['where is my wallet', '17:44', '12-Nov-2014']"

# %%
finmea = os.listdir('/home/wcmckee/visignsys/posts')

# %%
finmea
# Out:
# ['5e98dfab4326.html',
#  'df5aed94d944.meta',
#  '4a1d7fbd4af7.html',
#  'f78d6acee067.meta',
#  '1e1b72c3728f.meta',
#  'g\xe9~\xaf"\x80\xa8\x88\xc7X\xce\x83\x98\xe6\x15t.json',
#  '5e98dfab4326.meta',
#  'e51d650f3bd8.meta',
#  '417ca4249670.json',
#  '1ca6f0c7d074.html',
#  '9479b52fcb96.json',
#  '6dbfbbb9c12e.meta',
#  '6dbfbbb9c12e.html',
#  'ec335a74fef8.json',
#  '4611a6b53369.json',
#  'bd18983ba81c.meta',
#  '1bca31594654.html',
#  '63e5d8747f8f.meta',
#  'd7bfad4d84af.json',
#  '2a107fb19ec7.meta',
#  'f78d6acee067.html',
#  '03ba33c75d39.html',
#  'be7f3bba40a9.meta',
#  'de3a5ee926b8.meta',
#  '8f05ce526d45.meta',
#  '8457b8a9b2c0.meta',
#  '9479b52fcb96.meta',
#  '6ac58d43a79e.meta',
#  '91ece852eb61.meta',
#  'g\xe9~\xaf"\x80\xa8\x88\xc7X\xce\x83\x98\xe6\x15t.html',
#  'cee5c35e8560.json',
#  'ad81cda1984a.json',
#  'b9b5a2864917.json',
#  '1ca6f0c7d074.meta',
#  'd4da1b21b2ac.meta',
#  'f51c0885211f.json',
#  '81ae6564478e.html',
#  'fab0f7427796.meta',
#  'df5aed94d944.html',
#  '231f0cbc6422.html',
#  'a5fd59588711.html',
#  '125540ca4363.json',
#  '8bf3b3c045b2.meta',
#  '469b6be62e65.json',
#  '6e8165886873.meta',
#  'f63a51c5660b.html',
#  '2ce7b7e78b2d.meta',
#  '1ef070dc6543.meta',
#  '20923a94e619.json',
#  'c02c3d6eb062.json',
#  '086ef98a8bea.meta',
#  '63e5d8747f8f.html',
#  '03ba33c75d39.meta',
#  'ed90e8d91209.json',
#  '231f0cbc6422.meta',
#  '5e98dfab4326.json',
#  '08eed5e7841d.meta',
#  '0c4a69aa64c3.json',
#  'd948bc2cb2d5.json',
#  '8457b8a9b2c0.json',
#  'ff09eb4188ad.html',
#  'ad81cda1984a.meta',
#  'c02c3d6eb062.meta',
#  '6ac58d43a79e.html',
#  '3342b7e37622.meta',
#  'ed90e8d91209.meta',
#  '81ae6564478e.meta',
#  'f63a51c5660b.json',
#  'c9739e8e0ad8.json',
#  '20923a94e619.meta',
#  '08eed5e7841d.json',
#  '125540ca4363.meta',
#  '39848c9e2306.html',
#  '1ca6f0c7d074.json',
#  '8f05ce526d45.html',
#  'be7f3bba40a9.html',
#  '4a1d7fbd4af7.meta',
#  '1ef070dc6543.json',
#  '6e8165886873.json',
#  '891149fcb0cc.meta',
#  '4611a6b53369.meta',
#  '3342b7e37622.json',
#  '1bca31594654.meta',
#  '1e1b72c3728f.json',
#  '469b6be62e65.meta',
#  'd4da1b21b2ac.html',
#  '624bf3800e42.meta',
#  'c9739e8e0ad8.meta',
#  '0c4a69aa64c3.meta',
#  '39848c9e2306.meta',
#  'd7bfad4d84af.meta',
#  'e51d650f3bd8.html',
#  'b9b5a2864917.meta',
#  'a5fd59588711.json',
#  '2ce7b7e78b2d.json',
#  '417ca4249670.meta',
#  '5f866c12e733.meta',
#  'f30478d49490.meta',
#  'd948bc2cb2d5.html',
#  '5f866c12e733.html',
#  'df5aed94d944.json',
#  '49f5eeb93b58.meta',
#  'ff09eb4188ad.meta',
#  '\xff\xceX\xa6\x1b\xc7\xdf\x051\x81\x9d+\x95h\xf16.html',
#  '1bca31594654.json',
#  'ec335a74fef8.meta',
#  '9cce0605ff95.meta',
#  '9c5044cb8c12.json',
#  '8bf3b3c045b2.json',
#  'd948bc2cb2d5.meta',
#  '891149fcb0cc.json',
#  '086ef98a8bea.json',
#  'a5fd59588711.meta',
#  '81ae6564478e.json',
#  'f51c0885211f.meta',
#  '624bf3800e42.html',
#  '\xff\xceX\xa6\x1b\xc7\xdf\x051\x81\x9d+\x95h\xf16.json',
#  '9c5044cb8c12.meta',
#  'de3a5ee926b8.html',
#  'cee5c35e8560.meta',
#  'f30478d49490.html',
#  '231f0cbc6422.json',
#  '4a1d7fbd4af7.json',
#  'fab0f7427796.html',
#  '2a107fb19ec7.json',
#  '49f5eeb93b58.json',
#  '9cce0605ff95.html',
#  'be7f3bba40a9.json',
#  'bd18983ba81c.json',
#  'f63a51c5660b.meta']

# %%
medalis = []

# %%
for finm in finmea:
    if '.meta' in finm:
        medalis.append(finm)

# %%
altxt = []

# %%
for rmad in medalis:
    #print rmad
    with open('/home/wcmckee/visignsys/posts/' + rmad, 'r') as f:
            read_data = f.read()
            altxt.append(read_data)

# %%
checkem = []

# %%
for alt in altxt:
    print alt
    checkem.append(Series(alt))
# Out:
# ['ESW', 'William Mckee', '14-Oct-2014', 'busy with rico first thing and didnt sign in', '17:57']
# ['31-Oct-2014', 'ESW', 'William Mckee', 'omg broken', '04:39']
# ['11:24', 'ESW', 'testing after the pull', 'William Mckee', '27-Oct-2014']['11:24', 'testing night signout', '27-Oct-2014']
# ['ESW', 'interested in watching swimmers on way back from walk', '19:11', 'William Mckee', '21-Oct-2014']
# ['ESW', 'sunny day. going for walk.', '15:14', 'William Mckee', '12-Nov-2014']
# ['ESW', 'William Mckee', '12-Oct-2014', 'yay first day', '16:05']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']
# ['ESW', 'sanvi organised first walk. yay', '15:06', 'William Mckee', '09-Nov-2014']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']['31-Oct-2014', 'why', '04:38']
# ['ESW', 'going for walk', '20-Oct-2014', 'William Mckee', '16:18']
# ['ESW', '02-Nov-2014', '15:21', 'William Mckee', 'its a rainly morning. i want to be in the art area. ']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']
# ['ESW', 'late morning', '16:21', 'William Mckee', '27-Oct-2014']['27-Oct-2014', '18:46', 'counting with me on swing']['school kids loved mine and ashers dino chalk drawings', '27-Oct-2014', '19:28']
# ['ESW', '15-Oct-2014', 'William Mckee', 'login for thur. have a great day guys', '16:05']['forgot to signout  cuz i wwas annoyed with ird', '08:16', '16-Oct-2014']
# ['10-Nov-2014', 'ESW', 'strewberrys yum', 'William Mckee', '15:10']
# ['ESW', 'William Mckee', '12-Oct-2014', 'yay first day', '16:05']['12-Oct-2014', '19:35']
# ['13-Oct-2014', 'ESW', 'William Mckee', 'drinking a cup of herb tea before i start. beautiful day', '15:55']
# ['03-Nov-2014', '15:17', 'William Mckee', 'ESW', 'sunny day. organised first walk']
# ['16:00', 'ESW', 'William Mckee', '29-Oct-2014', 'hayden says blahblah']
# ['ESW', '15-Oct-2014', 'William Mckee', 'login for thur. have a great day guys', '16:05']['forgot to signout  cuz i wwas annoyed with ird', '08:16', '16-Oct-2014']['21:18', 'awesome first week. swinging and building, and drawing were highlights.', '16-Oct-2014']['didnt sign out friday', '16:13', '19-Oct-2014']
# ['ESW', '15-Oct-2014', 'William Mckee', '16:04', 'looking forward to a fun day']['test', '15-Oct-2014', '16:04']
# ['ESW', 'William Mckee', '14-Oct-2014', 'busy with rico first thing and didnt sign in', '17:57']['fun day', '19:05', '14-Oct-2014']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']['31-Oct-2014', 'why', '04:38']['31-Oct-2014', 'broken', '04:39']
# ['13-Oct-2014', 'ESW', 'William Mckee', 'drinking a cup of herb tea before i start. beautiful day', '15:55']['13-Oct-2014', '23:29', 'awesome climbing and swinging']
# ['15:16', 'ESW', '05-Nov-2014', 'William Mckee', 'everything is wet']
# ['ESW', 'sanvis kiwifruit looks delicous', 'William Mckee', '22-Oct-2014', '16:07']
# ['ESW', 'late morning', '16:21', 'William Mckee', '27-Oct-2014']['27-Oct-2014', '18:46', 'counting with me on swing']['school kids loved mine and ashers dino chalk drawings', '27-Oct-2014', '19:28']['testing logout', '19:31', '27-Oct-2014']
# ['ESW', '02-Nov-2014', '15:21', 'William Mckee', 'its a rainly morning. i want to be in the art area. ']['02-Nov-2014', 'art area drawing fox teeth and block building. ', '17:48']
# ['ESW', 'sunny day. going for walk.', '15:14', 'William Mckee', '12-Nov-2014']['where is my wallet', '17:44', '12-Nov-2014']
# ['ESW', 'going for walk', '20-Oct-2014', 'William Mckee', '16:18']['great day but headache', '20-Oct-2014', '18:45']
# ['16:00', 'ESW', 'William Mckee', '29-Oct-2014', 'hayden says blahblah']['outside with swing and chalk. drew on walk', '29-Oct-2014', '18:56']
# ['ESW', '15-Oct-2014', 'William Mckee', 'login for thur. have a great day guys', '16:05']
# ['ESW', 'beauty morning. food before i start', 'William Mckee', '04-Nov-2014', '15:11']['18:15', '04-Nov-2014', 'talj more. blast off still popular. r. drawing around kept less hyper.']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']['31-Oct-2014', 'why', '04:38']['31-Oct-2014', 'broken', '04:39']['31-Oct-2014', 'outz', '04:39']
# ['ESW', 'building this morning', 'William Mckee', '16:14', '19-Oct-2014']
# ['03-Nov-2014', '15:17', 'William Mckee', 'ESW', 'sunny day. organised first walk']['03-Nov-2014', '18:07', 'swings and chalk. Said 1:and blastoff']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']
# ['ESW', 'William Mckee', 'feeling a little fluish. sore throat and cough. ill take it easy', '21-Oct-2014', '16:10']
# ['ESW', '15-Oct-2014', 'William Mckee', 'login for thur. have a great day guys', '16:05']['forgot to signout  cuz i wwas annoyed with ird', '08:16', '16-Oct-2014']['21:18', 'awesome first week. swinging and building, and drawing were highlights.', '16-Oct-2014']
# ['17:36', 'ESW', 'William Mckee', 'swings today', '09-Nov-2014']
# ['17:36', 'ESW', 'William Mckee', 'swings today', '09-Nov-2014']['10-Nov-2014', '', '15:09']
# ['10-Nov-2014', 'ESW', 'strewberrys yum', 'William Mckee', '15:10']['10-Nov-2014', '17:45', 'i need someone to tag me so i can draw with a group']['15:17', '11-Nov-2014', 'wow that rain. hope im inside']['17:36', '11-Nov-2014', 'awesome day. outside, drawing, swinging.']
# ['ESW', 'late morning', '16:21', 'William Mckee', '27-Oct-2014']
# ['ESW', 'sanvis kiwifruit looks delicous', 'William Mckee', '22-Oct-2014', '16:07']['swinging on swings', '18:55', '22-Oct-2014']
# ['10-Nov-2014', 'ESW', 'strewberrys yum', 'William Mckee', '15:10']['10-Nov-2014', '17:45', 'i need someone to tag me so i can draw with a group']['15:17', '11-Nov-2014', 'wow that rain. hope im inside']
# ['ESW', 'late morning', '16:21', 'William Mckee', '27-Oct-2014']['27-Oct-2014', '18:46', 'counting with me on swing']
# ['ESW', 'William Mckee', 'no mother. work where its busy. sunny', '15:03', '06-Nov-2014']
# ['ESW', '28-Oct-2014', 'William Mckee', '15:57', 'rainy morning. likely to be inside']
# ['ESW', '28-Oct-2014', 'William Mckee', '15:57', 'rainy morning. likely to be inside']['28-Oct-2014', 'talked about tmnt', '19:03']
# ['11:24', 'ESW', 'testing after the pull', 'William Mckee', '27-Oct-2014']
# ['ESW', 'William Mckee', 'no mother. work where its busy. sunny', '15:03', '06-Nov-2014']['drew giant in chalk', '17:48', '06-Nov-2014']
# ['ESW', 'beauty morning. food before i start', 'William Mckee', '04-Nov-2014', '15:11']
# ['ESW', '15-Oct-2014', 'William Mckee', '16:04', 'looking forward to a fun day']
# ['ESW', '', 'William Mckee', '16:14', '19-Oct-2014']
# ['31-Oct-2014', 'ESW', 'William Mckee', 'omg broken', '04:39']['31-Oct-2014', 'omg no way', '04:39']
# ['15:16', 'ESW', '05-Nov-2014', 'William Mckee', 'everything is wet']['signout should of been 11 30. building black, drawing and creating dinos', '02:07', '06-Nov-2014']
# ['10-Nov-2014', 'ESW', 'strewberrys yum', 'William Mckee', '15:10']['10-Nov-2014', '17:45', 'i need someone to tag me so i can draw with a group']
# ['ESW', '17:09', 'William Mckee', 'in', '23-Oct-2014']

# %%
for chem in checkem:
    print chem
    sudo
# Out:
# ['ESW', 'William Mckee', '14-Oct-2014', 'busy with rico first thing and didnt sign in', '17:57']
# ['31-Oct-2014', 'ESW', 'William Mckee', 'omg broken', '04:39']
# ['11:24', 'ESW', 'testing after the pull', 'William Mckee', '27-Oct-2014']['11:24', 'testing night signout', '27-Oct-2014']
# ['ESW', 'interested in watching swimmers on way back from walk', '19:11', 'William Mckee', '21-Oct-2014']
# ['ESW', 'sunny day. going for walk.', '15:14', 'William Mckee', '12-Nov-2014']
# ['ESW', 'William Mckee', '12-Oct-2014', 'yay first day', '16:05']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']
# ['ESW', 'sanvi organised first walk. yay', '15:06', 'William Mckee', '09-Nov-2014']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']['31-Oct-2014', 'why', '04:38']
# ['ESW', 'going for walk', '20-Oct-2014', 'William Mckee', '16:18']
# ['ESW', '02-Nov-2014', '15:21', 'William Mckee', 'its a rainly morning. i want to be in the art area. ']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']
# ['ESW', 'late morning', '16:21', 'William Mckee', '27-Oct-2014']['27-Oct-2014', '18:46', 'counting with me on swing']['school kids loved mine and ashers dino chalk drawings', '27-Oct-2014', '19:28']
# ['ESW', '15-Oct-2014', 'William Mckee', 'login for thur. have a great day guys', '16:05']['forgot to signout  cuz i wwas annoyed with ird', '08:16', '16-Oct-2014']
# ['10-Nov-2014', 'ESW', 'strewberrys yum', 'William Mckee', '15:10']
# ['ESW', 'William Mckee', '12-Oct-2014', 'yay first day', '16:05']['12-Oct-2014', '19:35']
# ['13-Oct-2014', 'ESW', 'William Mckee', 'drinking a cup of herb tea before i start. beautiful day', '15:55']
# ['03-Nov-2014', '15:17', 'William Mckee', 'ESW', 'sunny day. organised first walk']
# ['16:00', 'ESW', 'William Mckee', '29-Oct-2014', 'hayden says blahblah']
# ['ESW', '15-Oct-2014', 'William Mckee', 'login for thur. have a great day guys', '16:05']['forgot to signout  cuz i wwas annoyed with ird', '08:16', '16-Oct-2014']['21:18', 'awesome first week. swinging and building, and drawing were highlights.', '16-Oct-2014']['didnt sign out friday', '16:13', '19-Oct-2014']
# ['ESW', '15-Oct-2014', 'William Mckee', '16:04', 'looking forward to a fun day']['test', '15-Oct-2014', '16:04']
# ['ESW', 'William Mckee', '14-Oct-2014', 'busy with rico first thing and didnt sign in', '17:57']['fun day', '19:05', '14-Oct-2014']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']['31-Oct-2014', 'why', '04:38']['31-Oct-2014', 'broken', '04:39']
# ['13-Oct-2014', 'ESW', 'William Mckee', 'drinking a cup of herb tea before i start. beautiful day', '15:55']['13-Oct-2014', '23:29', 'awesome climbing and swinging']
# ['15:16', 'ESW', '05-Nov-2014', 'William Mckee', 'everything is wet']
# ['ESW', 'sanvis kiwifruit looks delicous', 'William Mckee', '22-Oct-2014', '16:07']
# ['ESW', 'late morning', '16:21', 'William Mckee', '27-Oct-2014']['27-Oct-2014', '18:46', 'counting with me on swing']['school kids loved mine and ashers dino chalk drawings', '27-Oct-2014', '19:28']['testing logout', '19:31', '27-Oct-2014']
# ['ESW', '02-Nov-2014', '15:21', 'William Mckee', 'its a rainly morning. i want to be in the art area. ']['02-Nov-2014', 'art area drawing fox teeth and block building. ', '17:48']
# ['ESW', 'sunny day. going for walk.', '15:14', 'William Mckee', '12-Nov-2014']['where is my wallet', '17:44', '12-Nov-2014']
# ['ESW', 'going for walk', '20-Oct-2014', 'William Mckee', '16:18']['great day but headache', '20-Oct-2014', '18:45']
# ['16:00', 'ESW', 'William Mckee', '29-Oct-2014', 'hayden says blahblah']['outside with swing and chalk. drew on walk', '29-Oct-2014', '18:56']
# ['ESW', '15-Oct-2014', 'William Mckee', 'login for thur. have a great day guys', '16:05']
# ['ESW', 'beauty morning. food before i start', 'William Mckee', '04-Nov-2014', '15:11']['18:15', '04-Nov-2014', 'talj more. blast off still popular. r. drawing around kept less hyper.']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']['31-Oct-2014', 'why', '04:38']['31-Oct-2014', 'broken', '04:39']['31-Oct-2014', 'outz', '04:39']
# ['ESW', 'building this morning', 'William Mckee', '16:14', '19-Oct-2014']
# ['03-Nov-2014', '15:17', 'William Mckee', 'ESW', 'sunny day. organised first walk']['03-Nov-2014', '18:07', 'swings and chalk. Said 1:and blastoff']
# ['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']
# ['ESW', 'William Mckee', 'feeling a little fluish. sore throat and cough. ill take it easy', '21-Oct-2014', '16:10']
# ['ESW', '15-Oct-2014', 'William Mckee', 'login for thur. have a great day guys', '16:05']['forgot to signout  cuz i wwas annoyed with ird', '08:16', '16-Oct-2014']['21:18', 'awesome first week. swinging and building, and drawing were highlights.', '16-Oct-2014']
# ['17:36', 'ESW', 'William Mckee', 'swings today', '09-Nov-2014']
# ['17:36', 'ESW', 'William Mckee', 'swings today', '09-Nov-2014']['10-Nov-2014', '', '15:09']
# ['10-Nov-2014', 'ESW', 'strewberrys yum', 'William Mckee', '15:10']['10-Nov-2014', '17:45', 'i need someone to tag me so i can draw with a group']['15:17', '11-Nov-2014', 'wow that rain. hope im inside']['17:36', '11-Nov-2014', 'awesome day. outside, drawing, swinging.']
# ['ESW', 'late morning', '16:21', 'William Mckee', '27-Oct-2014']
# ['ESW', 'sanvis kiwifruit looks delicous', 'William Mckee', '22-Oct-2014', '16:07']['swinging on swings', '18:55', '22-Oct-2014']
# ['10-Nov-2014', 'ESW', 'strewberrys yum', 'William Mckee', '15:10']['10-Nov-2014', '17:45', 'i need someone to tag me so i can draw with a group']['15:17', '11-Nov-2014', 'wow that rain. hope im inside']
# ['ESW', 'late morning', '16:21', 'William Mckee', '27-Oct-2014']['27-Oct-2014', '18:46', 'counting with me on swing']
# ['ESW', 'William Mckee', 'no mother. work where its busy. sunny', '15:03', '06-Nov-2014']
# ['ESW', '28-Oct-2014', 'William Mckee', '15:57', 'rainy morning. likely to be inside']
# ['ESW', '28-Oct-2014', 'William Mckee', '15:57', 'rainy morning. likely to be inside']['28-Oct-2014', 'talked about tmnt', '19:03']
# ['11:24', 'ESW', 'testing after the pull', 'William Mckee', '27-Oct-2014']
# ['ESW', 'William Mckee', 'no mother. work where its busy. sunny', '15:03', '06-Nov-2014']['drew giant in chalk', '17:48', '06-Nov-2014']
# ['ESW', 'beauty morning. food before i start', 'William Mckee', '04-Nov-2014', '15:11']
# ['ESW', '15-Oct-2014', 'William Mckee', '16:04', 'looking forward to a fun day']
# ['ESW', '', 'William Mckee', '16:14', '19-Oct-2014']
# ['31-Oct-2014', 'ESW', 'William Mckee', 'omg broken', '04:39']['31-Oct-2014', 'omg no way', '04:39']
# ['15:16', 'ESW', '05-Nov-2014', 'William Mckee', 'everything is wet']['signout should of been 11 30. building black, drawing and creating dinos', '02:07', '06-Nov-2014']
# ['10-Nov-2014', 'ESW', 'strewberrys yum', 'William Mckee', '15:10']['10-Nov-2014', '17:45', 'i need someone to tag me so i can draw with a group']
# ['ESW', '17:09', 'William Mckee', 'in', '23-Oct-2014']

# %%
s = Series(altxt)

# %%
s.all
# Out:
# <bound method Series.all of 0     ['ESW', 'William Mckee', '14-Oct-2014', 'busy wit
# 1     ['31-Oct-2014', 'ESW', 'William Mckee', 'omg brok
# 2     ['11:24', 'ESW', 'testing after the pull', 'Willi
# 3     ['ESW', 'interested in watching swimmers on way b
# 4     ['ESW', 'sunny day. going for walk.', '15:14', 'W
# 5     ['ESW', 'William Mckee', '12-Oct-2014', 'yay firs
# 6     ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 7     ['ESW', 'sanvi organised first walk. yay', '15:06
# 8     ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 9     ['ESW', 'going for walk', '20-Oct-2014', 'William
# 10    ['ESW', '02-Nov-2014', '15:21', 'William Mckee',
# 11    ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 12    ['ESW', 'late morning', '16:21', 'William Mckee',
# 13    ['ESW', '15-Oct-2014', 'William Mckee', 'login fo
# 14    ['10-Nov-2014', 'ESW', 'strewberrys yum', 'Willia
# 15    ['ESW', 'William Mckee', '12-Oct-2014', 'yay firs
# 16    ['13-Oct-2014', 'ESW', 'William Mckee', 'drinking
# 17    ['03-Nov-2014', '15:17', 'William Mckee', 'ESW',
# 18    ['16:00', 'ESW', 'William Mckee', '29-Oct-2014',
# 19    ['ESW', '15-Oct-2014', 'William Mckee', 'login fo
# 20    ['ESW', '15-Oct-2014', 'William Mckee', '16:04',
# 21    ['ESW', 'William Mckee', '14-Oct-2014', 'busy wit
# 22    ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 23    ['13-Oct-2014', 'ESW', 'William Mckee', 'drinking
# 24    ['15:16', 'ESW', '05-Nov-2014', 'William Mckee',
# 25    ['ESW', 'sanvis kiwifruit looks delicous', 'Willi
# 26    ['ESW', 'late morning', '16:21', 'William Mckee',
# 27    ['ESW', '02-Nov-2014', '15:21', 'William Mckee',
# 28    ['ESW', 'sunny day. going for walk.', '15:14', 'W
# 29    ['ESW', 'going for walk', '20-Oct-2014', 'William
# 30    ['16:00', 'ESW', 'William Mckee', '29-Oct-2014',
# 31    ['ESW', '15-Oct-2014', 'William Mckee', 'login fo
# 32    ['ESW', 'beauty morning. food before i start', 'W
# 33    ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 34    ['ESW', 'building this morning', 'William Mckee',
# 35    ['03-Nov-2014', '15:17', 'William Mckee', 'ESW',
# 36    ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 37    ['ESW', 'William Mckee', 'feeling a little fluish
# 38    ['ESW', '15-Oct-2014', 'William Mckee', 'login fo
# 39    ['17:36', 'ESW', 'William Mckee', 'swings today',
# 40    ['17:36', 'ESW', 'William Mckee', 'swings today',
# 41    ['10-Nov-2014', 'ESW', 'strewberrys yum', 'Willia
# 42    ['ESW', 'late morning', '16:21', 'William Mckee',
# 43    ['ESW', 'sanvis kiwifruit looks delicous', 'Willi
# 44    ['10-Nov-2014', 'ESW', 'strewberrys yum', 'Willia
# 45    ['ESW', 'late morning', '16:21', 'William Mckee',
# 46    ['ESW', 'William Mckee', 'no mother. work where i
# 47    ['ESW', '28-Oct-2014', 'William Mckee', '15:57',
# 48    ['ESW', '28-Oct-2014', 'William Mckee', '15:57',
# 49    ['11:24', 'ESW', 'testing after the pull', 'Willi
# 50    ['ESW', 'William Mckee', 'no mother. work where i
# 51    ['ESW', 'beauty morning. food before i start', 'W
# 52    ['ESW', '15-Oct-2014', 'William Mckee', '16:04',
# 53    ['ESW', '', 'William Mckee', '16:14', '19-Oct-201
# 54    ['31-Oct-2014', 'ESW', 'William Mckee', 'omg brok
# 55    ['15:16', 'ESW', '05-Nov-2014', 'William Mckee',
# 56    ['10-Nov-2014', 'ESW', 'strewberrys yum', 'Willia
# 57    ['ESW', '17:09', 'William Mckee', 'in', '23-Oct-2
# Length: 58>

# %%
s[0]
# Out:
# "['ESW', 'William Mckee', '14-Oct-2014', 'busy with rico first thing and didnt sign in', '17:57']"

# %%
ndf = {}

# %%
df = DataFrame(s)

# %%
df
# Out:
#                                                     0
# 0   ['ESW', 'William Mckee', '14-Oct-2014', 'busy wit
# 1   ['31-Oct-2014', 'ESW', 'William Mckee', 'omg brok
# 2   ['11:24', 'ESW', 'testing after the pull', 'Willi
# 3   ['ESW', 'interested in watching swimmers on way b
# 4   ['ESW', 'sunny day. going for walk.', '15:14', 'W
# 5   ['ESW', 'William Mckee', '12-Oct-2014', 'yay firs
# 6   ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 7   ['ESW', 'sanvi organised first walk. yay', '15:06
# 8   ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 9   ['ESW', 'going for walk', '20-Oct-2014', 'William
# 10  ['ESW', '02-Nov-2014', '15:21', 'William Mckee',
# 11  ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 12  ['ESW', 'late morning', '16:21', 'William Mckee',
# 13  ['ESW', '15-Oct-2014', 'William Mckee', 'login fo
# 14  ['10-Nov-2014', 'ESW', 'strewberrys yum', 'Willia
# 15  ['ESW', 'William Mckee', '12-Oct-2014', 'yay firs
# 16  ['13-Oct-2014', 'ESW', 'William Mckee', 'drinking
# 17  ['03-Nov-2014', '15:17', 'William Mckee', 'ESW',
# 18  ['16:00', 'ESW', 'William Mckee', '29-Oct-2014',
# 19  ['ESW', '15-Oct-2014', 'William Mckee', 'login fo
# 20  ['ESW', '15-Oct-2014', 'William Mckee', '16:04',
# 21  ['ESW', 'William Mckee', '14-Oct-2014', 'busy wit
# 22  ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 23  ['13-Oct-2014', 'ESW', 'William Mckee', 'drinking
# 24  ['15:16', 'ESW', '05-Nov-2014', 'William Mckee',
# 25  ['ESW', 'sanvis kiwifruit looks delicous', 'Willi
# 26  ['ESW', 'late morning', '16:21', 'William Mckee',
# 27  ['ESW', '02-Nov-2014', '15:21', 'William Mckee',
# 28  ['ESW', 'sunny day. going for walk.', '15:14', 'W
# 29  ['ESW', 'going for walk', '20-Oct-2014', 'William
# 30  ['16:00', 'ESW', 'William Mckee', '29-Oct-2014',
# 31  ['ESW', '15-Oct-2014', 'William Mckee', 'login fo
# 32  ['ESW', 'beauty morning. food before i start', 'W
# 33  ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 34  ['ESW', 'building this morning', 'William Mckee',
# 35  ['03-Nov-2014', '15:17', 'William Mckee', 'ESW',
# 36  ['30-Oct-2014', 'ESW', 'William Mckee', 'its frid
# 37  ['ESW', 'William Mckee', 'feeling a little fluish
# 38  ['ESW', '15-Oct-2014', 'William Mckee', 'login fo
# 39  ['17:36', 'ESW', 'William Mckee', 'swings today',
# 40  ['17:36', 'ESW', 'William Mckee', 'swings today',
# 41  ['10-Nov-2014', 'ESW', 'strewberrys yum', 'Willia
# 42  ['ESW', 'late morning', '16:21', 'William Mckee',
# 43  ['ESW', 'sanvis kiwifruit looks delicous', 'Willi
# 44  ['10-Nov-2014', 'ESW', 'strewberrys yum', 'Willia
# 45  ['ESW', 'late morning', '16:21', 'William Mckee',
# 46  ['ESW', 'William Mckee', 'no mother. work where i
# 47  ['ESW', '28-Oct-2014', 'William Mckee', '15:57',
# 48  ['ESW', '28-Oct-2014', 'William Mckee', '15:57',
# 49  ['11:24', 'ESW', 'testing after the pull', 'Willi
# 50  ['ESW', 'William Mckee', 'no mother. work where i
# 51  ['ESW', 'beauty morning. food before i start', 'W
# 52  ['ESW', '15-Oct-2014', 'William Mckee', '16:04',
# 53  ['ESW', '', 'William Mckee', '16:14', '19-Oct-201
# 54  ['31-Oct-2014', 'ESW', 'William Mckee', 'omg brok
# 55  ['15:16', 'ESW', '05-Nov-2014', 'William Mckee',
# 56  ['10-Nov-2014', 'ESW', 'strewberrys yum', 'Willia
# 57  ['ESW', '17:09', 'William Mckee', 'in', '23-Oct-2

# %%
medajsn = []

# %%
for finm in finmea:
    if '.json' in finm:
        medajsn.append(finm)

# %%
medajsn
# Out:
# ['g\xe9~\xaf"\x80\xa8\x88\xc7X\xce\x83\x98\xe6\x15t.json',
#  '417ca4249670.json',
#  '9479b52fcb96.json',
#  'ec335a74fef8.json',
#  '4611a6b53369.json',
#  'd7bfad4d84af.json',
#  'cee5c35e8560.json',
#  'ad81cda1984a.json',
#  'b9b5a2864917.json',
#  'f51c0885211f.json',
#  '125540ca4363.json',
#  '469b6be62e65.json',
#  '20923a94e619.json',
#  'c02c3d6eb062.json',
#  'ed90e8d91209.json',
#  '5e98dfab4326.json',
#  '0c4a69aa64c3.json',
#  'd948bc2cb2d5.json',
#  '8457b8a9b2c0.json',
#  'f63a51c5660b.json',
#  'c9739e8e0ad8.json',
#  '08eed5e7841d.json',
#  '1ca6f0c7d074.json',
#  '1ef070dc6543.json',
#  '6e8165886873.json',
#  '3342b7e37622.json',
#  '1e1b72c3728f.json',
#  'a5fd59588711.json',
#  '2ce7b7e78b2d.json',
#  'df5aed94d944.json',
#  '1bca31594654.json',
#  '9c5044cb8c12.json',
#  '8bf3b3c045b2.json',
#  '891149fcb0cc.json',
#  '086ef98a8bea.json',
#  '81ae6564478e.json',
#  '\xff\xceX\xa6\x1b\xc7\xdf\x051\x81\x9d+\x95h\xf16.json',
#  '231f0cbc6422.json',
#  '4a1d7fbd4af7.json',
#  '2a107fb19ec7.json',
#  '49f5eeb93b58.json',
#  'be7f3bba40a9.json',
#  'bd18983ba81c.json']

# %%
remz = []

# %%
for mjsn in medajsn:
    #print rmad
    with open('/home/wcmckee/visignsys/posts/' + mjsn, 'r') as f:
            read_data = f.read()
            remz.append(read_data)

# %%
remz
# Out:
# ['{"signin-date": "31-Oct-2014", "reason": "esw", "firstname": "will", "signin-hrmin": "04:37:16", "lastname": "mckee", "signin-comment": "testing 123"}',
#  "['ESW', 'late morning', '16:21', 'William Mckee', '27-Oct-2014']['27-Oct-2014', '18:46', 'counting with me on swing']",
#  "['ESW', '15-Oct-2014', 'William Mckee', 'login for thur. have a great day guys', '16:05']['forgot to signout  cuz i wwas annoyed with ird', '08:16', '16-Oct-2014']",
#  "['ESW', 'William Mckee', 'no mother. work where its busy. sunny', '15:03', '06-Nov-2014']['drew giant in chalk', '17:48', '06-Nov-2014']",
#  "['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']",
#  "['ESW', 'sanvis kiwifruit looks delicous', 'William Mckee', '22-Oct-2014', '16:07']['swinging on swings', '18:55', '22-Oct-2014']",
#  "['10-Nov-2014', 'ESW', 'strewberrys yum', 'William Mckee', '15:10']['10-Nov-2014', '17:45', 'i need someone to tag me so i can draw with a group']",
#  "['ESW', '02-Nov-2014', '15:21', 'William Mckee', 'its a rainly morning. i want to be in the art area. ']['02-Nov-2014', 'art area drawing fox teeth and block building. ', '17:48']",
#  "['10-Nov-2014', 'ESW', 'strewberrys yum', 'William Mckee', '15:10']['10-Nov-2014', '17:45', 'i need someone to tag me so i can draw with a group']['15:17', '11-Nov-2014', 'wow that rain. hope im inside']",
#  "['31-Oct-2014', 'ESW', 'William Mckee', 'omg broken', '04:39']['31-Oct-2014', 'omg no way', '04:39']",
#  "['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']['31-Oct-2014', 'why', '04:38']['31-Oct-2014', 'broken', '04:39']['31-Oct-2014', 'outz', '04:39']",
#  "['ESW', '15-Oct-2014', 'William Mckee', 'login for thur. have a great day guys', '16:05']['forgot to signout  cuz i wwas annoyed with ird', '08:16', '16-Oct-2014']['21:18', 'awesome first week. swinging and building, and drawing were highlights.', '16-Oct-2014']",
#  "['ESW', 'beauty morning. food before i start', 'William Mckee', '04-Nov-2014', '15:11']['18:15', '04-Nov-2014', 'talj more. blast off still popular. r. drawing around kept less hyper.']",
#  "['ESW', 'sunny day. going for walk.', '15:14', 'William Mckee', '12-Nov-2014']['where is my wallet', '17:44', '12-Nov-2014']",
#  "['16:00', 'ESW', 'William Mckee', '29-Oct-2014', 'hayden says blahblah']['outside with swing and chalk. drew on walk', '29-Oct-2014', '18:56']",
#  '{"signin hrmin": "19:11", "reason": "ESW", "name": "William Mckee", "signin date": "21-Oct-2014", "signin comment": "interested in watching swimmers on way back from walk"}',
#  "['10-Nov-2014', 'ESW', 'strewberrys yum', 'William Mckee', '15:10']['10-Nov-2014', '17:45', 'i need someone to tag me so i can draw with a group']['15:17', '11-Nov-2014', 'wow that rain. hope im inside']['17:36', '11-Nov-2014', 'awesome day. outside, drawing, swinging.']",
#  '{"signin hrmin": "16:04", "reason": "ESW", "name": "William Mckee", "signin date": "15-Oct-2014", "signin comment": "looking forward to a fun day"}',
#  "['ESW', 'late morning', '16:21', 'William Mckee', '27-Oct-2014']['27-Oct-2014', '18:46', 'counting with me on swing']['school kids loved mine and ashers dino chalk drawings', '27-Oct-2014', '19:28']",
#  '{"signin hrmin": "17:09", "reason": "ESW", "name": "William Mckee", "signin date": "23-Oct-2014", "signin comment": "in"}',
#  "['17:36', 'ESW', 'William Mckee', 'swings today', '09-Nov-2014']['10-Nov-2014', '', '15:09']",
#  "['ESW', 'late morning', '16:21', 'William Mckee', '27-Oct-2014']['27-Oct-2014', '18:46', 'counting with me on swing']['school kids loved mine and ashers dino chalk drawings', '27-Oct-2014', '19:28']['testing logout', '19:31', '27-Oct-2014']",
#  '{"signin hrmin": "15:55", "reason": "ESW", "name": "William Mckee", "signin date": "13-Oct-2014", "signin comment": "drinking a cup of herb tea before i start. beautiful day"}',
#  "['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']['31-Oct-2014', 'why', '04:38']['31-Oct-2014', 'broken', '04:39']",
#  "['ESW', '15-Oct-2014', 'William Mckee', '16:04', 'looking forward to a fun day']['test', '15-Oct-2014', '16:04']",
#  "['ESW', 'going for walk', '20-Oct-2014', 'William Mckee', '16:18']['great day but headache', '20-Oct-2014', '18:45']",
#  "['11:24', 'ESW', 'testing after the pull', 'William Mckee', '27-Oct-2014']['11:24', 'testing night signout', '27-Oct-2014']",
#  '{"signin hrmin": "16:14", "reason": "ESW", "name": "William Mckee", "signin date": "19-Oct-2014", "signin comment": ""}',
#  "['ESW', 'William Mckee', '14-Oct-2014', 'busy with rico first thing and didnt sign in', '17:57']['fun day', '19:05', '14-Oct-2014']",
#  '{"signin hrmin": "17:57", "reason": "ESW", "name": "William Mckee", "signin date": "14-Oct-2014", "signin comment": "busy with rico first thing and didnt sign in"}',
#  '{"signin hrmin": "16:10", "reason": "ESW", "name": "William Mckee", "signin date": "21-Oct-2014", "signin comment": "feeling a little fluish. sore throat and cough. ill take it easy"}',
#  "['15:16', 'ESW', '05-Nov-2014', 'William Mckee', 'everything is wet']['signout should of been 11 30. building black, drawing and creating dinos', '02:07', '06-Nov-2014']",
#  "['ESW', '15-Oct-2014', 'William Mckee', 'login for thur. have a great day guys', '16:05']['forgot to signout  cuz i wwas annoyed with ird', '08:16', '16-Oct-2014']['21:18', 'awesome first week. swinging and building, and drawing were highlights.', '16-Oct-2014']['didnt sign out friday', '16:13', '19-Oct-2014']",
#  "['03-Nov-2014', '15:17', 'William Mckee', 'ESW', 'sunny day. organised first walk']['03-Nov-2014', '18:07', 'swings and chalk. Said 1:and blastoff']",
#  "['13-Oct-2014', 'ESW', 'William Mckee', 'drinking a cup of herb tea before i start. beautiful day', '15:55']['13-Oct-2014', '23:29', 'awesome climbing and swinging']",
#  '{"signin hrmin": "16:05", "reason": "ESW", "name": "William Mckee", "signin date": "15-Oct-2014", "signin comment": "login for thur. have a great day guys"}',
#  '{"signin-date": "31-Oct-2014", "reason": "checking the new script. test", "firstname": "William", "signin-hrmin": "03:59:31", "lastname": "Mckee", "signin-comment": "today should be aweseomes"}',
#  '{"signin hrmin": "16:07", "reason": "ESW", "name": "William Mckee", "signin date": "22-Oct-2014", "signin comment": "sanvis kiwifruit looks delicous"}',
#  '{"signin hrmin": "16:14", "reason": "ESW", "name": "William Mckee", "signin date": "19-Oct-2014", "signin comment": "building this morning"}',
#  "['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']['31-Oct-2014', 'omg testing out', '04:38']['31-Oct-2014', 'why', '04:38']",
#  "['ESW', '28-Oct-2014', 'William Mckee', '15:57', 'rainy morning. likely to be inside']['28-Oct-2014', 'talked about tmnt', '19:03']",
#  '{"signin hrmin": "16:18", "reason": "ESW", "name": "William Mckee", "signin date": "20-Oct-2014", "signin comment": "going for walk"}',
#  "['30-Oct-2014', 'ESW', 'William Mckee', 'its friday. sunny day. will we go on the first walk', '16:05']['19:02', 'throw at target', '30-Oct-2014']"]

# %%
import os
import time
import xlutils
import xlwt
import xlrd
import dominate
import sys
from dominate.tags import *
import json
#from sqlalchemy import Column, ForeignKey, Integer, String
#from sqlalchemy.ext.declarative import declarative_base
#from sqlalchemy.orm import relationship
#from sqlalchemy import create_engine

# <codecell>

lasnam = ('Mckee')
firnam = ('William')
dopz = ('04/12/1988')
mname = ('William Mckee')
ename = ('will@artcontrol.me')
signin = ('ESW')

wb = xlwt.Workbook()
ws = wb.add_sheet('visitor sign database')

# <codecell>

rangen = []

# <codecell>

for genz in range(8):
    #print os.urandom(128).encode('hex')
    rangen.append(os.urandom(128).encode('hex'))

# <codecell>

exran = os.urandom(128).encode('hex')

# <codecell>

ixran = os.urandom(128).encode('hex')

# <codecell>

rawdets = ['In-Date', 'In-Time', 'In-Code', 'Name', 'Reason', 'Out-Date', 'Out-Time']

# <codecell>

numroll = []
    #ws.write(0, det, )

# <codecell>

#for rad in rawdets:
 #   print rad
    #print len(rad)
#    print rad.upper()
    #range(20)

# <codecell>

ws.write(0, 0, 'In Date')
ws.write(0, 1, 'In Time')
ws.write(0, 2, 'In Code')
ws.write(0, 3, 'Name')
ws.write(0, 4, 'Reason')
ws.write(0, 5, 'Out Date')
ws.write(0, 6, 'Out Time')
ws.write(0, 7, 'Out Code')

# <codecell>

#strftime is %d (day), 

ws.write(1, 0, time.strftime("%d" + "-" + "%b" + "-" + "%Y"))

ws.write(1, 1, time.strftime("%H:%M"))

# <codecell>

#getname = raw_input('Name: ')
#getreason = raw_input('Reason: ')

# <codecell>

ws.write(1, 2, exran)

# <codecell>

ws.write(1, 3, mname)

# <codecell>

ws.write(1, 4, signin)

# <codecell>

#wb.save('/home/wcmckee/whai/' + xlvs)
wb.save('/home/wcmckee/whai/index.xls')

# <codecell>

usecom = raw_input('Comments: ')

# <codecell>

wsdict = {mname: rangen[0]}

# <codecell>

betdict = {'firstname': firnam}

# <codecell>

dayr = time.strftime("%d" + "-" + "%m" + "-" + "%Y")
hrmn = time.strftime("%H:%M:%S")

# <codecell>

betdict.update({'lastname': lasnam})
betdict.update({'reason': signin})
betdict.update({'signin-comment': usecom})
betdict.update({'signin-date': dayr})
betdict.update({'signin-hrmin': hrmn})

# <codecell>
s = Series(betdict)
betjsn = json.dumps(betdict)

# <codecell>

betjsn

# <codecell>

wsdict.update({time.strftime("%d" + "-" + "%m" + "-" + "%Y"): rangen[1]})

# <codecell>

wsdict.update({ time.strftime("%H:%M"): rangen[2]})

# <codecell>

wsdict.update({signin: rangen[3]})

# <codecell>

wsdict.update({usecom: rangen[4]})

# <codecell>


# <codecell>

doc = dominate.document(title='visitor sign sheet')

with doc.head:
    link(rel='stylesheet', href='style.css')
    script(type='text/javascript', src='script.js')

with doc:
    with div(id='header').add(ol()):
        for i in wsdict.keys():
            li(a(i))

    with div():
        attr(cls='body')
        p('last updated: ' + time.strftime("%H:%M"))

#print doc

# <codecell>

savindex = open('/home/wcmckee/visignsys/index.html', 'w')

# <codecell>

savindex.write(str(doc))
savindex.close()

# <codecell>

ixtwe = ixran[0:12]

# <codecell>

savpos = open('/home/wcmckee/visignsys/posts/' + ixtwe + '.html', 'w')
savpos.write(str(doc))
savpos.close()

# <codecell>

savpos = open('/home/wcmckee/visignsys/posts/' + ixtwe + '.meta', 'w')
savpos.write(str(wsdict))
savpos.close()

# <codecell>

savpos = open('/home/wcmckee/visignsys/index.meta', 'w')
savpos.write(str(wsdict.keys()))
savpos.close()

# <codecell>

savpos = open('/home/wcmckee/visignsys/index.json', 'w')
savpos.write(str(betjsn))
savpos.close()

# <codecell>

print 'helli'

# <codecell>
# Out:
# Comments: checking to see if it works
# helli

# %%
s
# Out:
# firstname                             William
# lastname                                Mckee
# reason                                    ESW
# signin-comment    checking to see if it works
# signin-date                       16-Nov-2014
# signin-hrmin                         11:56:01

# %%
mydef = DataFrame(s)

# %%
mydef
# Out:
#                                           0
# firstname                           William
# lastname                              Mckee
# reason                                  ESW
# signin-comment  checking to see if it works
# signin-date                     16-Nov-2014
# signin-hrmin                       11:56:01

# %%
urdef = mydef.copy()

# %%
urdef.to_html()
# Out:
# '<table border="1">\n  <thead>\n    <tr>\n      <th></th>\n      <th>0</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td><strong>firstname</strong></td>\n      <td>                     William</td>\n    </tr>\n    <tr>\n      <td><strong>lastname</strong></td>\n      <td>                       Mckee</td>\n    </tr>\n    <tr>\n      <td><strong>reason</strong></td>\n      <td>                         ESW</td>\n    </tr>\n    <tr>\n      <td><strong>signin-comment</strong></td>\n      <td> checking to see if it works</td>\n    </tr>\n    <tr>\n      <td><strong>signin-date</strong></td>\n      <td>                 16-Nov-2014</td>\n    </tr>\n    <tr>\n      <td><strong>signin-hrmin</strong></td>\n      <td>                    11:56:01</td>\n    </tr>\n  </tbody>\n</table>'

# %%
urdef.append(mydef)
# Out:
#                                           0
# firstname                           William
# lastname                              Mckee
# reason                                  ESW
# signin-comment  checking to see if it works
# signin-date                     16-Nov-2014
# signin-hrmin                       11:56:01
# firstname                           William
# lastname                              Mckee
# reason                                  ESW
# signin-comment  checking to see if it works
# signin-date                     16-Nov-2014
# signin-hrmin                       11:56:01

# %%
urdef
# Out:
#                                           0
# firstname                           William
# lastname                              Mckee
# reason                                  ESW
# signin-comment  checking to see if it works
# signin-date                     16-Nov-2014
# signin-hrmin                       11:56:01

# %%
pdran = pd.date_range(start='1-1-2000', end='12/31/2012', freq='B')

# %%
ser = Series(pdran)

# %%
ser
# Out:
# 0    2000-01-03 00:00:00
# 1    2000-01-04 00:00:00
# 2    2000-01-05 00:00:00
# 3    2000-01-06 00:00:00
# 4    2000-01-07 00:00:00
# 5    2000-01-10 00:00:00
# 6    2000-01-11 00:00:00
# 7    2000-01-12 00:00:00
# 8    2000-01-13 00:00:00
# 9    2000-01-14 00:00:00
# 10   2000-01-17 00:00:00
# 11   2000-01-18 00:00:00
# 12   2000-01-19 00:00:00
# 13   2000-01-20 00:00:00
# 14   2000-01-21 00:00:00
# ...
# 3376   2012-12-11 00:00:00
# 3377   2012-12-12 00:00:00
# 3378   2012-12-13 00:00:00
# 3379   2012-12-14 00:00:00
# 3380   2012-12-17 00:00:00
# 3381   2012-12-18 00:00:00
# 3382   2012-12-19 00:00:00
# 3383   2012-12-20 00:00:00
# 3384   2012-12-21 00:00:00
# 3385   2012-12-24 00:00:00
# 3386   2012-12-25 00:00:00
# 3387   2012-12-26 00:00:00
# 3388   2012-12-27 00:00:00
# 3389   2012-12-28 00:00:00
# 3390   2012-12-31 00:00:00
# Length: 3391
