# %% [markdown]
# **artcontrolme**
#
#
# Python script to deal with exported artcontrolme static files. The files are located at https://github.com/artcontrol/artcontrolme. '.wp' files that contain HTML of posts. '.meta' files contain name, hyperlink friendly name, date, cat, tags, id.

# %% [markdown]
# **TODO**

# %%
import requests
from bs4 import BeautifulSoup
import os

# %%
os.chdir('artcontrolme')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-191-f713f92905f0> in <module>()
# ----> 1 os.chdir('artcontrolme')
#
# OSError: [Errno 2] No such file or directory: 'artcontrolme'

# %%
os.chdir('posts')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-192-5f9febd55b4f> in <module>()
# ----> 1 os.chdir('posts')
#
# OSError: [Errno 2] No such file or directory: 'posts'

# %%
alfilz = []

# %%
for filz in os.listdir('/home/wcmckee/wcmckee/artcontrolme/posts'):
    print filz
    alfilz.append(filz)
# Out:
# lightsoff-pixel-ideas.meta
# ham-sketchbook.meta
# reddit-gets-drawn-group.wp
# cafrins-mask-collaborative-2.meta
# old-paintings.wp
# 5576.meta
# redditgetsdrawn-friday-night-lines.wp
# vincents-life-drawing-lee-thursday.wp
# 2465.wp
# circling-wellington-building-painting.meta
# 2086.wp
# bell-water.meta
# redditgetsdrawn-zombie.meta
# bacon-game-jam-07-hungry.meta
# blender-testing-action.wp
# double-female-model-monday.wp
# auxweltak.wp
# 1452.wp
# triger-concept-drawings.wp
# auckland-waterfront-concept-paint.wp
# 2322.meta
# 5108.wp
# i-wear-black-on-the-outside-cos-black-is-how-i-feel-on-the-inside.meta
# old-master-techniques.meta
# sketchy-sketchy-levin.meta
# strangegrace-illustration.meta
# just-two-colours.wp
# levin-tower-seq.meta
# friday-redditgetsdrawn.meta
# wellington-street-draw-halloween.wp
# takaka-drawing-class.meta
# email-to-my-mentor.meta
# levin-sketched-finals.wp
# wellington-street-draw-halloween.meta
# 4965.meta
# napier.wp
# ...

# %%
for bleh in alfilz:
    if '.wp' in bleh:
        print bleh
# Out:
# reddit-gets-drawn-group.wp
# old-paintings.wp
# redditgetsdrawn-friday-night-lines.wp
# vincents-life-drawing-lee-thursday.wp
# 2465.wp
# 2086.wp
# blender-testing-action.wp
# double-female-model-monday.wp
# auxweltak.wp
# 1452.wp
# triger-concept-drawings.wp
# auckland-waterfront-concept-paint.wp
# 5108.wp
# just-two-colours.wp
# wellington-street-draw-halloween.wp
# levin-sketched-finals.wp
# napier.wp
# inkscape-tuesday-redditgetsdrawn.wp
# andrew-a6-doodles.wp
# spyro-the-dragon-breathing-fire.wp
# promarkerny.wp
# saturday-morning.wp
# 5119.wp
# janelle-figure.wp
# welly-blend.wp
# sunday-morning.wp
# light-throw-tests.wp
# hutt-envro-paint.wp
# pencil-drawings-from-wellington.wp
# levin-water.wp
# chch-cbd-park-drawings.wp
# more-paintings.wp
# iograph-artworks.wp
# punk-jam.wp
# levin-rose.wp
# cafrin.wp
# alcemy-landscape.wp
# auckland-waterfont-plus-train-wait.wp
# global-game-jam-painting.wp
# frozen-path-eow-wip.wp
# may-monday-life-drawing.wp
# 5123.wp
# 35.wp
# ...

# %%
teqtxt
# Out:
# u'<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">\n<html>\n <head>\n  <title>Index of /artcontrolme/posts</title>\n </head>\n <body>\n<h1>Index of /artcontrolme/posts</h1>\n  <table>\n   <tr><th valign="top"><img src="/icons/blank.gif" alt="[ICO]"></th><th><a href="?C=N;O=D">Name</a></th><th><a href="?C=M;O=A">Last modified</a></th><th><a href="?C=S;O=A">Size</a></th><th><a href="?C=D;O=A">Description</a></th></tr>\n   <tr><th colspan="5"><hr></th></tr>\n<tr><td valign="top"><img src="/icons/back.gif" alt="[PARENTDIR]"></td><td><a href="/artcontrolme/">Parent Directory</a>       </td><td>&nbsp;</td><td align="right">  - </td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/unknown.gif" alt="[   ]"></td><td><a href="2h-pencil-works.meta">2h-pencil-works.meta</a>   </td><td align="right">2014-09-04 00:15  </td><td align="right">102 </td><td>&nbsp;</td></tr>\n<tr><td valign="top"><img src="/icons/text.gif" alt="[TXT]"></td><td><a href="2h-pencil-works.wp">2h-pencil-wo
# ...

# %%
arta =  artsi.find_all('a')

# %%
brta =  artsi.find_all('.meta')

# %%
#file = open('alcemy-landscape.wp', 'r')

#print file.read()

# %%
lisblog = []
metablog = []
dictblog = {}

# %%
teop = open('test.txt', 'w')

# %%
f=open('filename')
lines=f.readlines()
print lines[26]
print lines[30]

# %%
for bleh in alfilz:
    if '.meta' in bleh:
        #print bleh
        
        #filez = open('alcemy-landscape.wp', "r")
        #filez.read
        #filez.close()
        file = open(bleh, 'r')
        metaf = file.readlines()

        #print file.read()
        #metablog.append(file.readline())
        #metablog.append(file.readline())
        #metablog.append(file.readline())
        #print metaf[2]
        #adrdir = {metaf[0]: metaf[2]}
        chzdir = {metaf[1]: metaf[2]}#, file.readline()}
        print chzdir
        teop.write(file.read())
# Out:
# {'lightsoff-pixel-ideas\n': '2013-06-09 09:13:09\n'}
# {'ham-sketchbook\n': '2013-12-20 14:24:08\n'}
# {'cafrins-mask-collaborative-2\n': '2012-08-02 10:13:36\n'}
# {'5576\n': '2014-03-08 20:12:22\n'}
# {'circling-wellington-building-painting\n': '2013-03-13 11:06:30\n'}
# {'bell-water\n': '2013-01-17 01:18:35\n'}
# {'redditgetsdrawn-zombie\n': '2013-07-30 20:35:17\n'}
# {'bacon-game-jam-07-hungry\n': '2014-03-24 11:29:57\n'}
# {'2322\n': '2013-01-23 12:12:55\n'}
# {'i-wear-black-on-the-outside-cos-black-is-how-i-feel-on-the-inside\n': '2011-07-30 16:59:14\n'}
# {'old-master-techniques\n': '2012-01-20 00:46:10\n'}
# {'sketchy-sketchy-levin\n': '2012-08-14 06:59:27\n'}
# {'strangegrace-illustration\n': '2011-12-23 21:37:54\n'}
# {'levin-tower-seq\n': '2012-11-14 10:39:38\n'}
# {'friday-redditgetsdrawn\n': '2013-02-11 09:17:34\n'}
# {'takaka-drawing-class\n': '2012-07-22 23:17:56\n'}
# {'email-to-my-mentor\n': '2012-01-27 22:09:53\n'}
# ...

# %%
adrdir
# Out:
# {'DOTT\n': '2013-01-23 20:15:34\n'}

# %%
metablog
# Out:
# []

# %%
for neta in metablog:
    print neta
# Out:
# LightsOff pixel ideas
#
# lightsoff-pixel-ideas
#
# 2013-06-09 09:13:09
#
# Ham sketchbook
#
# ham-sketchbook
#
# 2013-12-20 14:24:08
#
# Cafrins Mask Collaborative 2
#
# cafrins-mask-collaborative-2
#
# 2012-08-02 10:13:36
#
# None
#
# 5576
#
# 2014-03-08 20:12:22
#
# Circling Wellington building painting
#
# circling-wellington-building-painting
#
# 2013-03-13 11:06:30
#
# Bell Water
#
# bell-water
#
# 2013-01-17 01:18:35
#
# redditgetsdrawn zombie
#
# redditgetsdrawn-zombie
#
# 2013-07-30 20:35:17
#
# bacon game jam 07 - hungry
#
# bacon-game-jam-07-hungry
#
# 2014-03-24 11:29:57
#
# steam punk
#
# 2322
#
# 2013-01-23 12:12:55
#
# I wear black on the outside cos black is how i feel on the inside
#
# i-wear-black-on-the-outside-cos-black-is-how-i-feel-on-the-inside
#
# 2011-07-30 16:59:14
#
# Old Master Techniques
#
# old-master-techniques
#
# 2012-01-20 00:46:10
#
# Sketchy Sketchy Levin
#
# sketchy-sketchy-levin
#
# 2012-08-14 06:59:27
#
# Strangegrace illustration
#
# ...

# %%
for bleh in alfilz:
    if '.wp' in bleh:
        #print bleh
        
        #filez = open('alcemy-landscape.wp', "r")
        #filez.read
        #filez.close()
        file = open(bleh, 'r')

        #print file.read()
        lisblog.append(file.read())
        teop.write(file.read())

# %%
len(lisblog)
# Out:
# 702

# %%
ls
# Out:
# 1131.meta
# 1131.wp
# 1153.meta
# 1153.wp
# 1365.meta
# 1365.wp
# 140.meta
# 140.wp
# 1432.meta
# 1432.wp
# 1449.meta
# 1449.wp
# 1452.meta
# 1452.wp
# 1503.meta
# 1503.wp
# 1519.meta
# 1519.wp
# 154.meta
# 154.wp
# 1597.meta
# 1597.wp
# 2086.meta
# 2086.wp
# 2197.meta
# 2197.wp
# 2211.meta
# 2211.wp
# 2271.meta
# 2271.wp
# 2296.meta
# 2296.wp
# 2322.meta
# 2322.wp
# 2333.meta
# 2333.wp
# 2351.meta
# 2351.wp
# 2465.meta
# 2465.wp
# 2535.meta
# 2535.wp
# 2562.meta
# 2562.wp
# 2725.meta
# 2725.wp
# 2784.meta
# 2784.wp
# 27.meta
# 27.wp
# 2800.meta
# 2800.wp
# 2804.meta
# 2804.wp
# 2819.meta
# 2819.wp
# 2852.meta
# 2852.wp
# 2h-pencil-works.meta
# 2h-pencil-works.wp
# 318.meta
# 318.wp
# 35.meta
# 35.wp
# 3d-render.meta
# 3d-render.wp
# 401.meta
# 401.wp
# 410.meta
# 410.wp
# 4778.meta
# 4778.wp
# 4784.meta
# 4784.wp
# 4804.meta
# 4804.wp
# 4812.meta
# 4812.wp
# 4860.meta
# 4860.wp
# 4923.meta
# 4923.wp
# 4965.meta
# 4965.wp
# 4990.meta
# 4990.wp
# 5015.meta
# 5015.wp
# 5023.meta
# ...

# %%
filez = open('alcemy-landscape.wp', "r")
filez.read()
filez.close()

# %%
print brta
# Out:
# []

# %%
import dominate
from dominate.tags import *

doc = dominate.document(title='artcontrolme')

with doc.head:
    link(rel='stylesheet', href='style.css')
    script(type='text/javascript', src='script.js')

with doc:
    with div(id='header').add(ol()):
        for bleh in alfilz:
            if '.wp' in bleh:
                li(str(bleh))

    #with div():
     #   attr(cls='body')
      #  p('Lorem ipsum..')

print doc
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>artcontrolme</title>
#     <link href="style.css" rel="stylesheet">
#     <script src="script.js" type="text/javascript"></script>
#   </head>
#   <body>
#     <div id="header">
#       <ol>
#         <li>reddit-gets-drawn-group.wp</li>
#         <li>old-paintings.wp</li>
#         <li>redditgetsdrawn-friday-night-lines.wp</li>
#         <li>vincents-life-drawing-lee-thursday.wp</li>
#         <li>2465.wp</li>
#         <li>2086.wp</li>
#         <li>blender-testing-action.wp</li>
#         <li>double-female-model-monday.wp</li>
#         <li>auxweltak.wp</li>
#         <li>1452.wp</li>
#         <li>triger-concept-drawings.wp</li>
#         <li>auckland-waterfront-concept-paint.wp</li>
#         <li>5108.wp</li>
#         <li>just-two-colours.wp</li>
#         <li>wellington-street-draw-halloween.wp</li>
#         <li>levin-sketched-finals.wp</li>
#         <li>napier.wp</li>
#         <li>inkscape-tuesday-redditgetsdrawn.wp</li>
# ...

# %%
artsi = BeautifulSoup(teqtxt)

print(artsi.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <html>
#  <head>
#   <title>
#    Index of /artcontrolme/posts
#   </title>
#  </head>
#  <body>
#   <h1>
#    Index of /artcontrolme/posts
#   </h1>
#   <table>
#    <tbody>
#     <tr>
#      <th valign="top">
#       <img alt="[ICO]" src="/icons/blank.gif"/>
#      </th>
#      <th>
#       <a href="?C=N;O=D">
#        Name
#       </a>
#      </th>
#      <th>
#       <a href="?C=M;O=A">
#        Last modified
#       </a>
#      </th>
#      <th>
#       <a href="?C=S;O=A">
#        Size
#       </a>
#      </th>
#      <th>
#       <a href="?C=D;O=A">
#        Description
#       </a>
#      </th>
#     </tr>
#     <tr>
#      <th colspan="5">
#       <hr/>
#      </th>
#     </tr>
#     <tr>
#      <td valign="top">
#       <img alt="[PARENTDIR]" src="/icons/back.gif"/>
#      </td>
#      <td>
#       <a href="/artcontrolme/">
#        Parent Directory
#       </a>
#      </td>
#      <td>
#      </td>
# ...
