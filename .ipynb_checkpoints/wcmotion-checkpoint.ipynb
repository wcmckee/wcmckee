# %%
import arrow
import os

# %%
utc = arrow.utcnow()

# %%
utc
# Out:
# <Arrow [2015-01-30T12:57:34.437874+00:00]>

# %%
utc.datetime
# Out:
# datetime.datetime(2015, 1, 30, 12, 57, 34, 437874, tzinfo=tzutc())

# %%
loca = utc.to('US/Pacific')

# %%
loca
# Out:
# <Arrow [2015-01-30T04:57:34.437874-08:00]>

# %%
loca.timestamp
# Out:
# 1422622654

# %%
loca.humanize()
# Out:
# u'just now'

# %%
ophoz = os.listdir('/home/wcmckee/motion/')

# %% [markdown]
# ok, got it listing direstories. Next i need to filter the stupid numbers added to the front and back.
#
# loop through each item, deleting the first 3 chars, and also deleteing the final three characters before the .jpg.
#
# Send the files into folders apropites to the yr/month/day. (worth filtering the files by hour folder also? min?

# %%
ophoz
# Out:
# ['07-20150124154205-10.jpg',
#  '31-20150124183500-21.jpg',
#  '22-20150124114941-15.jpg',
#  '02-20150131010317-07.jpg',
#  '18-20150123142256-29.jpg',
#  '24-20150124121122-15.jpg',
#  '07-20150124152507-07.jpg',
#  '16-20150123202843-16.jpg',
#  '16-20150124165238-20.jpg',
#  '03-20150124141854-17.jpg',
#  '16-20150123015033-00.jpg',
#  '33-20150124185759-20.jpg',
#  '02-20150131010733-00.jpg',
#  '10-20150123135307-21.jpg',
#  '27-20150124130235-04.jpg',
#  '03-20150124141721-19.jpg',
#  '16-20150123202853-07.jpg',
#  '22-20150124114805-07.jpg',
#  '02-20150131010713-04.jpg',
#  '18-20150123142051-10.jpg',
#  '06-20150124094636-01.jpg',
#  '06-20150124094555-01.jpg',
#  '53-20150124221508-05.jpg',
#  '09-20150124101753-23.jpg',
#  '32-20150124184743-19.jpg',
#  '16-20150124171428-07.jpg',
#  '01-20150124085633-06.jpg',
#  '55-20150124223145-05.jpg',
#  '22-20150124174930-06.jpg',
#  '24-20150124123749-03.jpg',
#  '18-20150123142309-09.jpg',
#  '14-20150124162844-15.jpg',
# ...
