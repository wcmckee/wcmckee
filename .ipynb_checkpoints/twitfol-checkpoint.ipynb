# %%
from TwitterFollowBot import TwitterBot
import requests
import json
import praw
import random
my_bot = TwitterBot()

# %%
r = praw.Reddit(user_agent='wcmckeepython')

# %%
scribred = ['python', 'programming', 'web_design', 'coding', 'hacking', 'opensource', 'compsci']

# %%
randscr = random.choice(scribred)

# %%
hashse = ('#' + randscr)

# %%
hashse
# Out:
# '#web_design'

# %%
getnewr = r.get_subreddit(randscr)

# %%
#for getr in getnewr:
#    print (getr)

# %%
getrsub = getnewr.get_random_submission()

# %%
gtia = getrsub.title

# %%
gurl = getrsub.url

# %%
my_bot.send_tweet(gtia + ' ' + gurl + ' ' + hashse)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Aug 06 08:27:44 +0000 2015',
#  'entities': {'hashtags': [{'indices': [44, 55], 'text': 'web_design'}],
#   'symbols': [],
#   'urls': [{'display_url': 'reddit.com/r/web_design/c…',
#     'expanded_url': 'http://www.reddit.com/r/web_design/comments/3fxt95/drupal_reader_plugin/',
#     'indices': [21, 43],
#     'url': 'http://t.co/QxHzWYgaFc'}],
#   'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 629207213790236672,
#  'id_str': '629207213790236672',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'pt',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://wcmckee.com" rel="nofollow">wcmckee-tweet</a>',
#  'text': 'Drupal Reader Plugin http://t.co/QxHzWYgaFc #web_design',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Sat Sep 20 08:09:39 +0000 2014',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Twitter account for http://t.co/KQYI4xVTZd. Open Source Python Software and Web Development.',
#   'entities': {'description': {'urls': [{'display_url': 'wcmckee.com',
#       'expanded_url': 'http://wcmckee.com',
#       'indices': [20, 42],
#       'url': 'http://t.co/KQYI4xVTZd'}]},
#    'url': {'urls': [{'display_url': 'wcmckee.com',
#       'expanded_url': 'http://wcmckee.com',
#       'indices': [0, 22],
#       'url': 'http://t.co/KQYI4xVTZd'}]}},
#   'favourites_count': 176,
#   'follow_request_sent': False,
#   'followers_count': 56,
#   'following': False,
#   'friends_count': 524,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 2821347210,
#   'id_str': '2821347210',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 11,
#   'location': 'Hamilton City, New Zealand',
#   'name': 'wcmckee',
#   'notifications': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2821347210/1411200759',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/621211385746161664/tGchJstD_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/621211385746161664/tGchJstD_normal.jpg',
#   'profile_link_color': 'FFCC4D',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'protected': False,
#   'screen_name': 'wcmckeedotcom',
#   'statuses_count': 482,
#   'time_zone': 'Wellington',
#   'url': 'http://t.co/KQYI4xVTZd',
#   'utc_offset': 43200,
#   'verified': False}}

# %%
#reqjok = requests.get('http://tambal.azurewebsites.net/joke/random')

# %%
#jsjok = reqjok.text

# %%
#dicjok = json.loads(jsjok)

# %%
#str(dicjok.values())
# Out:
# "dict_values(['What do you call a cow with no legs? Ground beef'])"

# %%
#for dicv in dicjok.values():
#    print (dicv)
#    my_bot.send_tweet(dicv)

# %%
#my_bot.sync_follows()

# %%
#my_bot.auto_unfollow_nonfollowers()
# Out:
# unfollowed 55732226
# unfollowed 45748741
# unfollowed 30618637
# unfollowed 15395859
# unfollowed 911304212
# unfollowed 19416598
# unfollowed 2513530136
# unfollowed 258947612
# unfollowed 14595881
# unfollowed 974957611
# unfollowed 1068951084
# unfollowed 299333932
# unfollowed 46300208
# unfollowed 31563056
# unfollowed 14215989
# unfollowed 199512118
# unfollowed 1201186872
# unfollowed 15830587
# unfollowed 85906238
# unfollowed 17257535
# unfollowed 282235968
# unfollowed 385617473
# unfollowed 17645638
# unfollowed 1072766282
# unfollowed 81036364
# unfollowed 2444384845
# unfollowed 142828623
# unfollowed 403703632
# unfollowed 2326251343
# unfollowed 18318677
# unfollowed 26402904
# unfollowed 18201693
# unfollowed 471550563
# unfollowed 35846244
# unfollowed 621644646
# unfollowed 215739497
# unfollowed 131044458
# unfollowed 8678252
# unfollowed 45496942
# unfollowed 251757939
# unfollowed 2922095220
# unfollowed 170371192
# unfollowed 15154811
# unfollowed 2460368252
# unfollowed 14897792
# unfollowed 2367111
# unfollowed 495517322
# unfollowed 26616462
# unfollowed 547273872
# unfollowed 27031193
# unfollowed 99173786
# unfollowed 53560219
# unfollowed 48230811
# unfollowed 507345308
# unfollowed 987181214
# unfollowed 5980062
# unfollowed 156080288
# unfollowed 860076704
# unfollowed 106536353
# unfollowed 750554018
# unfollowed 15379361
# unfollowed 22161061
# unfollowed 314758565
# unfollowed 554377128
# unfollowed 14355626
# unfollowed 123378347
# unfollowed 1259181
# unfollowed 244991150
# unfollowed 2578087086
# unfollowed 13919662
# unfollowed 902981550
# unfollowed 594206135
# unfollowed 1963020727
# unfollowed 42558652
# unfollowed 123500736
# unfollowed 239754433
# unfollowed 22839233
# unfollowed 31936449
# unfollowed 125695429
# unfollowed 34270918
# unfollowed 80589255
# unfollowed 16408008
# unfollowed 245547210
# unfollowed 228015307
# unfollowed 24253645
# unfollowed 242340054
# unfollowed 14259159
# unfollowed 17985496
# unfollowed 1702492890
# unfollowed 53893339
# unfollowed 33341148
# unfollowed 16067035
# unfollowed 12448992
# unfollowed 115494880
# unfollowed 1428575976
# unfollowed 575655913
# unfollowed 15256301
# unfollowed 48966898
# unfollowed 332367354
# unfollowed 993743611
# unfollowed 293116923
# unfollowed 26862591

# %%
my_bot.auto_follow_followers()

# %%
mybowp = my_bot.search_tweets('wordpress')

# %%
mybp = mybowp['statuses'][0]['user']['screen_name']

# %%
my_bot.send_tweet('@' + mybp + ' ' + 'Check out Nikola - secure and simple unlike Wordpress ' + 'https://getnikola.com/')
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Aug 06 07:21:58 +0000 2015',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [{'display_url': 'getnikola.com',
#     'expanded_url': 'https://getnikola.com/',
#     'indices': [71, 94],
#     'url': 'https://t.co/Nabi8sTsK2'}],
#   'user_mentions': [{'id': 905784546,
#     'id_str': '905784546',
#     'indices': [0, 16],
#     'name': 'In A Country Cottage',
#     'screen_name': 'InACountryCttge'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 629190660877201412,
#  'id_str': '629190660877201412',
#  'in_reply_to_screen_name': 'InACountryCttge',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': 905784546,
#  'in_reply_to_user_id_str': '905784546',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://wcmckee.com" rel="nofollow">wcmckee-tweet</a>',
#  'text': '@InACountryCttge Check out Nikola - secure and simple unlike Wordpress https://t.co/Nabi8sTsK2',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Sat Sep 20 08:09:39 +0000 2014',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Twitter account for http://t.co/KQYI4xVTZd. Open Source Python Software and Web Development.',
#   'entities': {'description': {'urls': [{'display_url': 'wcmckee.com',
#       'expanded_url': 'http://wcmckee.com',
#       'indices': [20, 42],
#       'url': 'http://t.co/KQYI4xVTZd'}]},
#    'url': {'urls': [{'display_url': 'wcmckee.com',
#       'expanded_url': 'http://wcmckee.com',
#       'indices': [0, 22],
#       'url': 'http://t.co/KQYI4xVTZd'}]}},
#   'favourites_count': 175,
#   'follow_request_sent': False,
#   'followers_count': 55,
#   'following': False,
#   'friends_count': 414,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 2821347210,
#   'id_str': '2821347210',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 10,
#   'location': 'Hamilton City, New Zealand',
#   'name': 'wcmckee',
#   'notifications': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2821347210/1411200759',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/621211385746161664/tGchJstD_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/621211385746161664/tGchJstD_normal.jpg',
#   'profile_link_color': 'FFCC4D',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'protected': False,
#   'screen_name': 'wcmckeedotcom',
#   'statuses_count': 480,
#   'time_zone': 'Wellington',
#   'url': 'http://t.co/KQYI4xVTZd',
#   'utc_offset': 43200,
#   'verified': False}}

# %%
sectalk = my_bot.search_tweets('blackhat2015')

# %%
sectalk['search_metadata']
# Out:
# {'completed_in': 0.093,
#  'count': 100,
#  'max_id': 629132920066822145,
#  'max_id_str': '629132920066822145',
#  'next_results': '?max_id=629103306070212608&q=blackhat2015&count=100&include_entities=1&result_type=recent',
#  'query': 'blackhat2015',
#  'refresh_url': '?since_id=629132920066822145&q=blackhat2015&result_type=recent&include_entities=1',
#  'since_id': 0,
#  'since_id_str': '0'}

# %%
sectalk['statuses'][0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Aug 06 03:32:31 +0000 2015',
#  'entities': {'hashtags': [{'indices': [0, 13], 'text': 'BlackHat2015'}],
#   'symbols': [],
#   'urls': [{'display_url': 'reg.cx/2gy8',
#     'expanded_url': 'http://reg.cx/2gy8',
#     'indices': [74, 96],
#     'url': 'http://t.co/6i9RwEPQVa'}],
#   'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 629132920066822145,
#  'id_str': '629132920066822145',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://ifttt.com" rel="nofollow">IFTTT</a>',
#  'text': '#BlackHat2015 Chinese gang shoots down aerospace security with MSFT flaws http://t.co/6i9RwEPQVa',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Mon Sep 02 16:47:00 +0000 2013',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'The home of technology news, brought to you by @MaXFalstein, @MaX_MSD & @MaXSaxeDesign Twitter bot: @MSDHawk',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'blog.maxsaxedesign.co.uk',
#       'expanded_url': 'http://blog.maxsaxedesign.co.uk',
#       'indices': [0, 22],
#       'url': 'http://t.co/sZpU1miNUV'}]}},
#   'favourites_count': 826,
#   'follow_request_sent': False,
#   'followers_count': 261,
#   'following': False,
#   'friends_count': 169,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 1722831672,
#   'id_str': '1722831672',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 136,
#   'location': 'Fareham, Hampshire',
#   'name': 'MSD Tech News',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1722831672/1378146972',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000401233303/b9ece8070d56e49d2db3a4f2849afe60_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000401233303/b9ece8070d56e49d2db3a4f2849afe60_normal.jpeg',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'MSDTechNews',
#   'statuses_count': 52853,
#   'time_zone': 'London',
#   'url': 'http://t.co/sZpU1miNUV',
#   'utc_offset': 3600,
#   'verified': False}}

# %%
sectalk
# Out:
# {'search_metadata': {'completed_in': 0.093,
#   'count': 100,
#   'max_id': 629132920066822145,
#   'max_id_str': '629132920066822145',
#   'next_results': '?max_id=629103306070212608&q=blackhat2015&count=100&include_entities=1&result_type=recent',
#   'query': 'blackhat2015',
#   'refresh_url': '?since_id=629132920066822145&q=blackhat2015&result_type=recent&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Aug 06 03:32:31 +0000 2015',
#    'entities': {'hashtags': [{'indices': [0, 13], 'text': 'BlackHat2015'}],
#     'symbols': [],
#     'urls': [{'display_url': 'reg.cx/2gy8',
#       'expanded_url': 'http://reg.cx/2gy8',
#       'indices': [74, 96],
#       'url': 'http://t.co/6i9RwEPQVa'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 629132920066822145,
#    'id_str': '629132920066822145',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://ifttt.com" rel="nofollow">IFTTT</a>',
#    'text': '#BlackHat2015 Chinese gang shoots down aerospace security with MSFT flaws http://t.co/6i9RwEPQVa',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Sep 02 16:47:00 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'The home of technology news, brought to you by @MaXFalstein, @MaX_MSD & @MaXSaxeDesign Twitter bot: @MSDHawk',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'blog.maxsaxedesign.co.uk',
#         'expanded_url': 'http://blog.maxsaxedesign.co.uk',
#         'indices': [0, 22],
#         'url': 'http://t.co/sZpU1miNUV'}]}},
#     'favourites_count': 826,
#     'follow_request_sent': False,
#     'followers_count': 261,
#     'following': False,
#     'friends_count': 169,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1722831672,
#     'id_str': '1722831672',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 136,
#     'location': 'Fareham, Hampshire',
#     'name': 'MSD Tech News',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1722831672/1378146972',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000401233303/b9ece8070d56e49d2db3a4f2849afe60_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000401233303/b9ece8070d56e49d2db3a4f2849afe60_normal.jpeg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MSDTechNews',
#     'statuses_count': 52853,
#     'time_zone': 'London',
#     'url': 'http://t.co/sZpU1miNUV',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Aug 06 03:32:00 +0000 2015',
#    'entities': {'hashtags': [{'indices': [0, 13], 'text': 'BlackHat2015'}],
#     'symbols': [],
#     'urls': [{'display_url': 'reg.cx/2gy8',
#       'expanded_url': 'http://reg.cx/2gy8',
#       'indices': [74, 96],
#       'url': 'http://t.co/Kg8VnwV0Pb'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 629132788302807040,
#    'id_str': '629132788302807040',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://theregister.co.uk/" rel="nofollow">Vulture Central</a>',
#    'text': '#BlackHat2015 Chinese gang shoots down aerospace security with MSFT flaws http://t.co/Kg8VnwV0Pb',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Sep 28 13:24:46 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Biting the hand that feeds IT. Technology and science news for world+dog. Send tipoffs to news@theregister.co.uk',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'theregister.co.uk',
#         'expanded_url': 'http://www.theregister.co.uk/',
#         'indices': [0, 22],
#         'url': 'http://t.co/Gxz6SJm95D'}]}},
#     'favourites_count': 208,
#     'follow_request_sent': False,
#     'followers_count': 43252,
#     'following': False,
#     'friends_count': 59,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 78012548,
#     'id_str': '78012548',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1970,
#     'location': 'London/San Francisco/Sydney',
#     'name': 'The Register',
#     'notifications': False,
#     'profile_background_color': '292A2B',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000099035295/7621a6d721ecae23dc5d3df4c6c4279a.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000099035295/7621a6d721ecae23dc5d3df4c6c4279a.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/78012548/1411639635',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000628331746/5f111cbaa05662491e9e2468a26fd364_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000628331746/5f111cbaa05662491e9e2468a26fd364_normal.png',
#     'profile_link_color': 'DD2E44',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '2E2D2E',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'TheRegister',
#     'statuses_count': 72348,
#     'time_zone': 'London',
#     'url': 'http://t.co/Gxz6SJm95D',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Aug 06 03:31:59 +0000 2015',
#    'entities': {'hashtags': [{'indices': [0, 13], 'text': 'BlackHat2015'}],
#     'symbols': [],
#     'urls': [{'display_url': 'reg.cx/2gy8',
#       'expanded_url': 'http://reg.cx/2gy8',
#       'indices': [74, 96],
#       'url': 'http://t.co/bEIvhNomgH'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 629132784108478464,
#    'id_str': '629132784108478464',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://theregister.co.uk/" rel="nofollow">Vulture Central</a>',
#    'text': '#BlackHat2015 Chinese gang shoots down aerospace security with MSFT flaws http://t.co/bEIvhNomgH',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Apr 27 20:28:21 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "Headlines from @TheRegister, with added snark and banter from Vulture Central's backroom gremlins. Tech news and analysis for world+dog.",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'theregister.co.uk',
#         'expanded_url': 'http://www.theregister.co.uk',
#         'indices': [0, 22],
#         'url': 'http://t.co/7w5Uyygwsh'}]}},
#     'favourites_count': 1,
#     'follow_request_sent': False,
#     'followers_count': 7532,
#     'following': False,
#     'friends_count': 1,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 35850390,
#     'id_str': '35850390',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 704,
#     'location': 'UK/USA/Australia',
#     'name': 'The Register',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1569320207/reg_75-red_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1569320207/reg_75-red_normal.png',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ElReg',
#     'statuses_count': 75166,
#     'time_zone': 'London',
#     'url': 'http://t.co/7w5Uyygwsh',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Aug 06 03:31:24 +0000 2015',
#    'entities': {'hashtags': [{'indices': [97, 103], 'text': 'BHUSA'},
#      {'indices': [104, 117], 'text': 'BlackHat2015'}],
#     'media': [{'display_url': 'pic.twitter.com/wr1DIKAiVz',
#       'expanded_url': 'http://twitter.com/jenjwood1/status/629055620495228928/photo/1',
#       'id': 629055604070289408,
#       'id_str': '629055604070289408',
#       'indices': [118, 140],
#       'media_url': 'http://pbs.twimg.com/media/CLravTCUEAAOKM5.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/CLravTCUEAAOKM5.jpg',
#       'sizes': {'large': {'h': 944, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 553, 'resize': 'fit', 'w': 600},
#        'small': {'h': 313, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 629055620495228928,
#       'source_status_id_str': '629055620495228928',
#       'source_user_id': 21053158,
#       'source_user_id_str': '21053158',
#       'type': 'photo',
#       'url': 'http://t.co/wr1DIKAiVz'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 21053158,
#       'id_str': '21053158',
#       'indices': [3, 13],
#       'name': 'Jennifer Wood',
#       'screen_name': 'jenjwood1'},
#      {'id': 120136596,
#       'id_str': '120136596',
#       'indices': [75, 88],
#       'name': 'KymPossible',
#       'screen_name': 'Kym_Possible'},
#      {'id': 17928011,
#       'id_str': '17928011',
#       'indices': [89, 96],
#       'name': 'jkouns',
#       'screen_name': 'jkouns'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 629132638025084928,
#    'id_str': '629132638025084928',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 7,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Aug 05 22:25:21 +0000 2015',
#     'entities': {'hashtags': [{'indices': [82, 88], 'text': 'BHUSA'},
#       {'indices': [89, 102], 'text': 'BlackHat2015'}],
#      'media': [{'display_url': 'pic.twitter.com/wr1DIKAiVz',
#        'expanded_url': 'http://twitter.com/jenjwood1/status/629055620495228928/photo/1',
#        'id': 629055604070289408,
#        'id_str': '629055604070289408',
#        'indices': [103, 125],
#        'media_url': 'http://pbs.twimg.com/media/CLravTCUEAAOKM5.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/CLravTCUEAAOKM5.jpg',
#        'sizes': {'large': {'h': 944, 'resize': 'fit', 'w': 1024},
#         'medium': {'h': 553, 'resize': 'fit', 'w': 600},
#         'small': {'h': 313, 'resize': 'fit', 'w': 340},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'http://t.co/wr1DIKAiVz'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 120136596,
#        'id_str': '120136596',
#        'indices': [60, 73],
#        'name': 'KymPossible',
#        'screen_name': 'Kym_Possible'},
#       {'id': 17928011,
#        'id_str': '17928011',
#        'indices': [74, 81],
#        'name': 'jkouns',
#        'screen_name': 'jkouns'}]},
#     'favorite_count': 5,
#     'favorited': False,
#     'geo': None,
#     'id': 629055620495228928,
#     'id_str': '629055620495228928',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': {'attributes': {},
#      'bounding_box': {'coordinates': [[[-115.2092535, 35.984784],
#         [-115.0610763, 35.984784],
#         [-115.0610763, 36.137145],
#         [-115.2092535, 36.137145]]],
#       'type': 'Polygon'},
#      'contained_within': [],
#      'country': 'United States',
#      'country_code': 'US',
#      'full_name': 'Paradise, NV',
#      'id': '8fa6d7a33b83ef26',
#      'name': 'Paradise',
#      'place_type': 'city',
#      'url': 'https://api.twitter.com/1.1/geo/id/8fa6d7a33b83ef26.json'},
#     'possibly_sensitive': False,
#     'retweet_count': 7,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Stranger Danger! What is the risk from 3rd party libraries? @Kym_Possible @jkouns #BHUSA #BlackHat2015 http://t.co/wr1DIKAiVz',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Feb 17 01:42:17 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Follows cybersecurity, science and tech. Florida Gator, traveler and NASA groupie. Comms @Kaspersky NA. Tweets represent my personal views.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'linkedin.com/in/jenniferjwo…',
#          'expanded_url': 'http://www.linkedin.com/in/jenniferjwood',
#          'indices': [0, 22],
#          'url': 'http://t.co/MNJQvRyafc'}]}},
#      'favourites_count': 571,
#      'follow_request_sent': False,
#      'followers_count': 1594,
#      'following': True,
#      'friends_count': 979,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 21053158,
#      'id_str': '21053158',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 19,
#      'location': 'Boston, MA',
#      'name': 'Jennifer Wood',
#      'notifications': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/853209242/4cec1cb93e2d0df4b7765bfac227e294.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/853209242/4cec1cb93e2d0df4b7765bfac227e294.jpeg',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21053158/1418765562',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/500495933801385984/0-d-woyT_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/500495933801385984/0-d-woyT_normal.jpeg',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '95E8EC',
#      'profile_text_color': '3C3940',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'jenjwood1',
#      'statuses_count': 2963,
#      'time_zone': 'Pacific Time (US & Canada)',
#      'url': 'http://t.co/MNJQvRyafc',
#      'utc_offset': -25200,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @jenjwood1: Stranger Danger! What is the risk from 3rd party libraries? @Kym_Possible @jkouns #BHUSA #BlackHat2015 http://t.co/wr1DIKAiVz',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Aug 30 15:07:49 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Pesimista crónico, laburante de la seguridad informática, ex consultor.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 141,
#     'follow_request_sent': False,
#     'followers_count': 61,
#     'following': False,
#     'friends_count': 154,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 184813929,
#     'id_str': '184813929',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 9,
#     'location': '',
#     'name': 'Ignacio Marambio',
#     'notifications': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/184813929/1352859029',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000845654982/8482ce8b4c383943f71782a939c57074_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000845654982/8482ce8b4c383943f71782a939c57074_normal.jpeg',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'imarambiocatan',
#     'statuses_count': 4530,
#     'time_zone': 'Buenos Aires',
#     'url': None,
#     'utc_offset': -10800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Aug 06 03:30:58 +0000 2015',
#    'entities': {'hashtags': [{'indices': [12, 25], 'text': 'BlackHat2015'}],
#     'symbols': [],
#     'urls': [{'display_url': 'eset.la/1SNWDKi',
#       'expanded_url': 'http://eset.la/1SNWDKi',
#       'indices': [62, 84],
#       'url': 'http://t.co/3m3AKlUHLN'}],
#     'user_mentions': [{'id': 42804564,
#       'id_str': '42804564',
#       'indices': [3, 10],
#       'name': 'ESET Latinoamérica',
#       'screen_name': 'ESETLA'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 629132527916216321,
#    'id_str': '629132527916216321',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 8,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Aug 06 01:30:02 +0000 2015',
#     'entities': {'hashtags': [{'indices': [0, 13], 'text': 'BlackHat2015'}],
#      'symbols': [],
#      'urls': [{'display_url': 'eset.la/1SNWDKi',
#        'expanded_url': 'http://eset.la/1SNWDKi',
#        'indices': [50, 72],
#        'url': 'http://t.co/3m3AKlUHLN'}],
#      'user_mentions': []},
#     'favorite_count': 3,
#     'favorited': False,
#     'geo': None,
#     'id': 629102094444703745,
#     'id_str': '629102094444703745',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 8,
#     'retweeted': False,
#     'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#     'text': '#BlackHat2015: Malware en el centro de la escena. http://t.co/3m3AKlUHLN  ¡Leelo en WeLiveSecurity!',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed May 27 03:26:10 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Seguridad, noticias, tendencias, guías y consejos para que puedas disfrutar de la tecnología de forma más segura. http://t.co/d9CZuSNEl0',
#      'entities': {'description': {'urls': [{'display_url': 'facebook.com/ESETLA',
#          'expanded_url': 'http://www.facebook.com/ESETLA',
#          'indices': [114, 136],
#          'url': 'http://t.co/d9CZuSNEl0'}]},
#       'url': {'urls': [{'display_url': 'eset-la.com',
#          'expanded_url': 'http://www.eset-la.com',
#          'indices': [0, 22],
#          'url': 'http://t.co/IMhdznUzfM'}]}},
#      'favourites_count': 3819,
#      'follow_request_sent': False,
#      'followers_count': 12192,
#      'following': False,
#      'friends_count': 5993,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 42804564,
#      'id_str': '42804564',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 329,
#      'location': 'Latinoamérica',
#      'name': 'ESET Latinoamérica',
#      'notifications': False,
#      'profile_background_color': '01768F',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000096468846/f26d6fa7e892e12bb3fc93545a2003e1.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000096468846/f26d6fa7e892e12bb3fc93545a2003e1.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/42804564/1424898526',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/570691845336743936/9IDQnvx0_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/570691845336743936/9IDQnvx0_normal.jpeg',
#      'profile_link_color': '01768F',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'D9E4EB',
#      'profile_text_color': '80878D',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'ESETLA',
#      'statuses_count': 11874,
#      'time_zone': 'Buenos Aires',
#      'url': 'http://t.co/IMhdznUzfM',
#      'utc_offset': -10800,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @ESETLA: #BlackHat2015: Malware en el centro de la escena. http://t.co/3m3AKlUHLN  ¡Leelo en WeLiveSecurity!',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Mar 14 19:11:02 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Joven amante de la tecnología, la música y la poesía. Sígueme en http://t.co/KNSHFUBIkA',
#     'entities': {'description': {'urls': [{'display_url': 'instagram.com/jrevillah',
#         'expanded_url': 'http://instagram.com/jrevillah',
#         'indices': [65, 87],
#         'url': 'http://t.co/KNSHFUBIkA'}]},
#      'url': {'urls': [{'display_url': 'javierelpoeta.blogspot.com',
#         'expanded_url': 'http://javierelpoeta.blogspot.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/yCrGfO9tr2'}]}},
#     'favourites_count': 1325,
#     'follow_request_sent': False,
#     'followers_count': 464,
#     'following': False,
#     'friends_count': 985,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 1267775216,
#     'id_str': '1267775216',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 4,
#     'location': 'Lima - Perú',
#     'name': 'Javier Revilla',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/542760705737252864/Ld-NXXre.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/542760705737252864/Ld-NXXre.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1267775216/1418236381',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3381827379/77e9a31f6b34c9fa741d74b91bf40e2d_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3381827379/77e9a31f6b34c9fa741d74b91bf40e2d_normal.jpeg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'jrevillah',
#     'statuses_count': 828,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'url': 'http://t.co/yCrGfO9tr2',
#     'utc_offset': -14400,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Aug 06 03:26:17 +0000 2015',
#    'entities': {'hashtags': [{'indices': [97, 103], 'text': 'BHUSA'},
#      {'indices': [104, 117], 'text': 'BlackHat2015'}],
#     'media': [{'display_url': 'pic.twitter.com/wr1DIKAiVz',
#       'expanded_url': 'http://twitter.com/jenjwood1/status/629055620495228928/photo/1',
#       'id': 629055604070289408,
#       'id_str': '629055604070289408',
#       'indices': [118, 140],
#       'media_url': 'http://pbs.twimg.com/media/CLravTCUEAAOKM5.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/CLravTCUEAAOKM5.jpg',
#       'sizes': {'large': {'h': 944, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 553, 'resize': 'fit', 'w': 600},
#        'small': {'h': 313, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 629055620495228928,
#       'source_status_id_str': '629055620495228928',
#       'source_user_id': 21053158,
#       'source_user_id_str': '21053158',
#       'type': 'photo',
#       'url': 'http://t.co/wr1DIKAiVz'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 21053158,
#       'id_str': '21053158',
#       'indices': [3, 13],
#       'name': 'Jennifer Wood',
#       'screen_name': 'jenjwood1'},
#      {'id': 120136596,
#       'id_str': '120136596',
#       'indices': [75, 88],
#       'name': 'KymPossible',
#       'screen_name': 'Kym_Possible'},
#      {'id': 17928011,
#       'id_str': '17928011',
#       'indices': [89, 96],
#       'name': 'jkouns',
#       'screen_name': 'jkouns'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 629131352458158080,
#    'id_str': '629131352458158080',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 7,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Aug 05 22:25:21 +0000 2015',
#     'entities': {'hashtags': [{'indices': [82, 88], 'text': 'BHUSA'},
#       {'indices': [89, 102], 'text': 'BlackHat2015'}],
#      'media': [{'display_url': 'pic.twitter.com/wr1DIKAiVz',
#        'expanded_url': 'http://twitter.com/jenjwood1/status/629055620495228928/photo/1',
#        'id': 629055604070289408,
#        'id_str': '629055604070289408',
#        'indices': [103, 125],
#        'media_url': 'http://pbs.twimg.com/media/CLravTCUEAAOKM5.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/CLravTCUEAAOKM5.jpg',
#        'sizes': {'large': {'h': 944, 'resize': 'fit', 'w': 1024},
#         'medium': {'h': 553, 'resize': 'fit', 'w': 600},
#         'small': {'h': 313, 'resize': 'fit', 'w': 340},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'http://t.co/wr1DIKAiVz'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 120136596,
#        'id_str': '120136596',
#        'indices': [60, 73],
#        'name': 'KymPossible',
#        'screen_name': 'Kym_Possible'},
#       {'id': 17928011,
#        'id_str': '17928011',
#        'indices': [74, 81],
#        'name': 'jkouns',
#        'screen_name': 'jkouns'}]},
#     'favorite_count': 5,
#     'favorited': False,
#     'geo': None,
#     'id': 629055620495228928,
#     'id_str': '629055620495228928',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': {'attributes': {},
#      'bounding_box': {'coordinates': [[[-115.2092535, 35.984784],
#         [-115.0610763, 35.984784],
#         [-115.0610763, 36.137145],
#         [-115.2092535, 36.137145]]],
#       'type': 'Polygon'},
#      'contained_within': [],
#      'country': 'United States',
#      'country_code': 'US',
#      'full_name': 'Paradise, NV',
#      'id': '8fa6d7a33b83ef26',
#      'name': 'Paradise',
#      'place_type': 'city',
#      'url': 'https://api.twitter.com/1.1/geo/id/8fa6d7a33b83ef26.json'},
#     'possibly_sensitive': False,
#     'retweet_count': 7,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Stranger Danger! What is the risk from 3rd party libraries? @Kym_Possible @jkouns #BHUSA #BlackHat2015 http://t.co/wr1DIKAiVz',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Feb 17 01:42:17 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Follows cybersecurity, science and tech. Florida Gator, traveler and NASA groupie. Comms @Kaspersky NA. Tweets represent my personal views.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'linkedin.com/in/jenniferjwo…',
#          'expanded_url': 'http://www.linkedin.com/in/jenniferjwood',
#          'indices': [0, 22],
#          'url': 'http://t.co/MNJQvRyafc'}]}},
#      'favourites_count': 571,
#      'follow_request_sent': False,
#      'followers_count': 1594,
#      'following': True,
#      'friends_count': 979,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 21053158,
#      'id_str': '21053158',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 19,
#      'location': 'Boston, MA',
#      'name': 'Jennifer Wood',
#      'notifications': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/853209242/4cec1cb93e2d0df4b7765bfac227e294.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/853209242/4cec1cb93e2d0df4b7765bfac227e294.jpeg',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21053158/1418765562',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/500495933801385984/0-d-woyT_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/500495933801385984/0-d-woyT_normal.jpeg',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '95E8EC',
#      'profile_text_color': '3C3940',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'jenjwood1',
#      'statuses_count': 2963,
#      'time_zone': 'Pacific Time (US & Canada)',
#      'url': 'http://t.co/MNJQvRyafc',
#      'utc_offset': -25200,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @jenjwood1: Stranger Danger! What is the risk from 3rd party libraries? @Kym_Possible @jkouns #BHUSA #BlackHat2015 http://t.co/wr1DIKAiVz',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri May 11 05:01:12 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Solaris Engineer at Sun^H^H^HOracle (Release management, Security, X11);\nhttp://t.co/BqHlSt3Euv Board member; general hacker/geek',
#     'entities': {'description': {'urls': [{'display_url': 'X.Org',
#         'expanded_url': 'http://X.Org',
#         'indices': [73, 95],
#         'url': 'http://t.co/BqHlSt3Euv'}]},
#      'url': {'urls': [{'display_url': 'blogs.oracle.com/alanc/',
#         'expanded_url': 'http://blogs.oracle.com/alanc/',
#         'indices': [0, 22],
#         'url': 'http://t.co/DuOL004apd'}]}},
#     'favourites_count': 95,
#     'follow_request_sent': False,
#     'followers_count': 1112,
#     'following': False,
#     'friends_count': 697,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 5950412,
#     'id_str': '5950412',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 71,
#     'location': 'San Francisco Bay Area, Calif.',
#     'name': 'Alan Coopersmith',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/65740434/x-weave.gif',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/65740434/x-weave.gif',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/5950412/1398213235',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/311504970/alanc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/311504970/alanc_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'alanc',
#     'statuses_count': 3511,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'url': 'http://t.co/DuOL004apd',
#     'utc_offset': -25200,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Aug 06 03:26:06 +0000 2015',
#    'entities': {'hashtags': [{'indices': [136, 149], 'text': 'BlackHat2015'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 30973,
#       'id_str': '30973',
#       'indices': [109, 119],
#       'name': 'Starbucks Coffee',
#       'screen_name': 'Starbucks'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 629131305104441344,
#    'id_str': '629131305104441344',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Air travel LHR -&gt; LAS $4200\nHotel on Strip 5x$300 = $1500\nFood and Ent -&gt; $2100\nWeek bitching abt line @Starbucks -&gt; Priceless\n#BlackHat2015',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Oct 11 23:28:50 +0000 2010',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'InfoSec, Risk Mgt, and Motorcycles.  Author: Assessing and Managing Security Risk in IT: a Structured Methodology.  Educator.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1295,
#     'follow_request_sent': False,
#     'followers_count': 537,
#     'following': False,
#     'friends_count': 962,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 201484405,
#     'id_str': '201484405',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 33,
#     'location': 'Wash. DC, Cary, NC, bag claim',
#     'name': 'John McCumber',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/201484405/1423087857',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/478591296400289792/ARTLYp9Y_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/478591296400289792/ARTLYp9Y_normal.png',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'johnmccumber',
#     'statuses_count': 2343,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'url': None,
#     'utc_offset': -14400,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Aug 06 03:24:59 +0000 2015',
#    'entities': {'hashtags': [{'indices': [11, 24], 'text': 'BlackHat2015'}],
#     'media': [{'display_url': 'pic.twitter.com/Is9qR1eWvQ',
#       'expanded_url': 'http://twitter.com/owasp/status/629039393790013440/photo/1',
#       'id': 629039370675224576,
#       'id_str': '629039370675224576',
#       'indices': [121, 140],
#       'media_url': 'http://pbs.twimg.com/media/CLrL-Y7VAAAVpjx.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/CLrL-Y7VAAAVpjx.jpg',
#       'sizes': {'large': {'h': 768, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 450, 'resize': 'fit', 'w': 600},
#        'small': {'h': 255, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 629039393790013440,
#       'source_status_id_str': '629039393790013440',
#       'source_user_id': 16048357,
#       'source_user_id_str': '16048357',
#       'type': 'photo',
#       'url': 'http://t.co/Is9qR1eWvQ'}],
#     'symbols': [],
#     'urls': [{'display_url': 'owasp.org/index.php/OWAS…',
#       'expanded_url': 'https://www.owasp.org/index.php/OWASP_WASC_Distributed_Web_Honeypots_Project',
#       'indices': [97, 120],
#       'url': 'https://t.co/Oz3mtnbUHh'}],
#     'user_mentions': [{'id': 16048357,
#       'id_str': '16048357',
#       'indices': [3, 9],
#       'name': 'owasp',
#       'screen_name': 'owasp'},
#      {'id': 135907568,
#       'id_str': '135907568',
#       'indices': [33, 46],
#       'name': 'Ryan Barnett',
#       'screen_name': 'ryancbarnett'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 629131024052715520,
#    'id_str': '629131024052715520',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 22,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Aug 05 21:20:53 +0000 2015',
#     'entities': {'hashtags': [{'indices': [0, 13], 'text': 'BlackHat2015'}],
#      'media': [{'display_url': 'pic.twitter.com/Is9qR1eWvQ',
#        'expanded_url': 'http://twitter.com/owasp/status/629039393790013440/photo/1',
#        'id': 629039370675224576,
#        'id_str': '629039370675224576',
#        'indices': [110, 132],
#        'media_url': 'http://pbs.twimg.com/media/CLrL-Y7VAAAVpjx.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/CLrL-Y7VAAAVpjx.jpg',
#        'sizes': {'large': {'h': 768, 'resize': 'fit', 'w': 1024},
#         'medium': {'h': 450, 'resize': 'fit', 'w': 600},
#         'small': {'h': 255, 'resize': 'fit', 'w': 340},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'http://t.co/Is9qR1eWvQ'}],
#      'symbols': [],
#      'urls': [{'display_url': 'owasp.org/index.php/OWAS…',
#        'expanded_url': 'https://www.owasp.org/index.php/OWASP_WASC_Distributed_Web_Honeypots_Project',
#        'indices': [86, 109],
#        'url': 'https://t.co/Oz3mtnbUHh'}],
#      'user_mentions': [{'id': 135907568,
#        'id_str': '135907568',
#        'indices': [22, 35],
#        'name': 'Ryan Barnett',
#        'screen_name': 'ryancbarnett'}]},
#     'favorite_count': 18,
#     'favorited': False,
#     'geo': None,
#     'id': 629039393790013440,
#     'id_str': '629039393790013440',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 22,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': '#BlackHat2015 Arsenal @ryancbarnett presenting OWASP Distributed Web Honeypot Project https://t.co/Oz3mtnbUHh http://t.co/Is9qR1eWvQ',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Aug 29 22:41:34 +0000 2008',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Our mission is to make application security visible so that people and organizations can make informed decisions about application security risk.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'owasp.org',
#          'expanded_url': 'https://www.owasp.org',
#          'indices': [0, 23],
#          'url': 'https://t.co/aoXb0Eb6kY'}]}},
#      'favourites_count': 669,
#      'follow_request_sent': False,
#      'followers_count': 54895,
#      'following': False,
#      'friends_count': 325,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 16048357,
#      'id_str': '16048357',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 1445,
#      'location': 'Global',
#      'name': 'owasp',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/60407757/owasp_logo_normal.gif',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/60407757/owasp_logo_normal.gif',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'owasp',
#      'statuses_count': 3989,
#      'time_zone': 'Hawaii',
#      'url': 'https://t.co/aoXb0Eb6kY',
#      'utc_offset': -36000,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @owasp: #BlackHat2015 Arsenal @ryancbarnett presenting OWASP Distributed Web Honeypot Project https://t.co/Oz3mtnbUHh http://t.co/Is9qR1…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Feb 22 11:43:18 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 335,
#     'follow_request_sent': False,
#     'followers_count': 391,
#     'following': False,
#     'friends_count': 416,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 255969484,
#     'id_str': '255969484',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 17,
#     'location': '',
#     'name': 'Mateo Martinez',
#     'notifications': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/208700589/x24acf9ba2b363cfc15a650eb820e7d6.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/208700589/x24acf9ba2b363cfc15a650eb820e7d6.jpg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/255969484/1399144067',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/599537497429909505/cscR-YaL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/599537497429909505/cscR-YaL_normal.jpg',
#     'profile_link_color': '9DDD95',
#     'profile_sidebar_border_color': 'A0EEF5',
#     'profile_sidebar_fill_color': '1A3F57',
#     'profile_text_color': '72B9BF',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MateoMartinez1',
#     'statuses_count': 2564,
#     'time_zone': None,
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Aug 06 03:20:32 +0000 2015',
#    'entities': {'hashtags': [{'indices': [107, 120], 'text': 'Blackhat2015'},
#      {'indices': [121, 132], 'text': 'FrenchKiss'},
#      {'indices': [133, 140], 'text': 'MenageATrois'}],
#     'symbols': [],
#     'urls': [{'display_url': 'fr.slideshare.net/endrazine',
#       'expanded_url': 'http://fr.slideshare.net/endrazine',
#       'indices': [84, 106],
#       'url': 'http://t.co/cMT4oJmaVE'}],
#     'user_mentions': [{'id': 39526207,
#       'id_str': '39526207',
#       'indices': [3, 13],
#       'name': 'Jonathan Brossard',
#       'screen_name': 'endrazine'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 629129905196953601,
#    'id_str': '629129905196953601',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 13,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Aug 06 01:27:58 +0000 2015',
#     'entities': {'hashtags': [{'indices': [92, 105], 'text': 'Blackhat2015'},
#       {'indices': [106, 117], 'text': 'FrenchKiss'},
#       {'indices': [118, 131], 'text': 'MenageATrois'}],
#      'symbols': [],
#      'urls': [{'display_url': 'fr.slideshare.net/endrazine',
#        'expanded_url': 'http://fr.slideshare.net/endrazine',
#        'indices': [69, 91],
#        'url': 'http://t.co/cMT4oJmaVE'}],
#      'user_mentions': []},
#     'favorite_count': 11,
#     'favorited': False,
#     'geo': None,
#     'id': 629101577232461824,
#     'id_str': '629101577232461824',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 13,
# ...
#    'geo': None,
#    'id': 629103666247536641,
#    'id_str': '629103666247536641',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'Thycotic booth....is this how Mike Tyson says psychotic? #bhusa #blackhat2015 @Thycotic @MikeTyson http://t.co/C1ngRMGlG9',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Aug 02 15:23:38 +0000 2015',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'We Are Watching.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'itsecurityplanet.com',
#         'expanded_url': 'http://www.itsecurityplanet.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/WnRQWJ3BI1'}]}},
#     'favourites_count': 7,
#     'follow_request_sent': False,
#     'followers_count': 69,
#     'following': False,
#     'friends_count': 1070,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 3304386296,
#     'id_str': '3304386296',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 3,
#     'location': 'Los Angeles, CA',
#     'name': 'ITSP Magazine',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3304386296/1438539027',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/627904381250174976/fYJTpCG3_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/627904381250174976/fYJTpCG3_normal.png',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'ITSPMagazine',
#     'statuses_count': 85,
#     'time_zone': None,
#     'url': 'http://t.co/WnRQWJ3BI1',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Aug 06 01:35:27 +0000 2015',
#    'entities': {'hashtags': [{'indices': [86, 99], 'text': 'BlackHat2015'}],
#     'symbols': [],
#     'urls': [{'display_url': 'github.com/gfoss/PSRecon/',
#       'expanded_url': 'https://github.com/gfoss/PSRecon/',
#       'indices': [109, 132],
#       'url': 'https://t.co/vFtzFXwiKs'}],
#     'user_mentions': [{'id': 369862421,
#       'id_str': '369862421',
#       'indices': [3, 13],
#       'name': '†ϲΘѓѓΘՏїΘл†',
#       'screen_name': 'c0rr0s10n'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 629103460898721792,
#    'id_str': '629103460898721792',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Aug 06 01:17:34 +0000 2015',
#     'entities': {'hashtags': [{'indices': [71, 84], 'text': 'BlackHat2015'}],
#      'symbols': [],
#      'urls': [{'display_url': 'github.com/gfoss/PSRecon/',
#        'expanded_url': 'https://github.com/gfoss/PSRecon/',
#        'indices': [94, 117],
#        'url': 'https://t.co/vFtzFXwiKs'}],
#      'user_mentions': []},
#     'favorite_count': 0,
#     'favorited': False,
#     'geo': None,
#     'id': 629098958564896768,
#     'id_str': '629098958564896768',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'PSRecon: PowerShell Incident Response - Live Forensic Data Acquisition #BlackHat2015 &gt;&gt; https://t.co/vFtzFXwiKs',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Sep 08 02:16:19 +0000 2011',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '|| #Security #Guru, #Vulnerability #Researcher in thirst of #Knowledge. War is an art, so welcome to the canvas. || #Intelligence #OffensiveSecurity #ExploitDev',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'defense.gov',
#          'expanded_url': 'http://www.defense.gov',
#          'indices': [0, 22],
#          'url': 'http://t.co/nx8Zxh4Vux'}]}},
#      'favourites_count': 1150,
#      'follow_request_sent': False,
#      'followers_count': 691,
#      'following': False,
#      'friends_count': 470,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 369862421,
#      'id_str': '369862421',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 31,
#      'location': '/srv/*',
#      'name': '†ϲΘѓѓΘՏїΘл†',
#      'notifications': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/468310252140507136/x2aCOD8u.png',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/468310252140507136/x2aCOD8u.png',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/369862421/1416761502',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/548875474231779330/JW_Xh8EW_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548875474231779330/JW_Xh8EW_normal.png',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'c0rr0s10n',
#      'statuses_count': 7089,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'url': 'http://t.co/nx8Zxh4Vux',
#      'utc_offset': -14400,
#      'verified': False}},
#    'source': '<a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>',
#    'text': 'RT @c0rr0s10n: PSRecon: PowerShell Incident Response - Live Forensic Data Acquisition #BlackHat2015 &gt;&gt; https://t.co/vFtzFXwiKs',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Oct 25 12:25:24 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'IT Geek !',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'zigmax.net',
#         'expanded_url': 'http://www.zigmax.net',
#         'indices': [0, 22],
#         'url': 'http://t.co/8NaaqxY8QQ'}]}},
#     'favourites_count': 21,
#     'follow_request_sent': False,
#     'followers_count': 154,
#     'following': False,
#     'friends_count': 973,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 397983435,
#     'id_str': '397983435',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'fr',
#     'listed_count': 24,
#     'location': 'Quebec ',
#     'name': 'ZiGMaX',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/571504356220112896/GoiAcv2T_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/571504356220112896/GoiAcv2T_normal.jpeg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'zig_max',
#     'statuses_count': 995,
#     'time_zone': 'Paris',
#     'url': 'http://t.co/8NaaqxY8QQ',
#     'utc_offset': 7200,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Aug 06 01:34:50 +0000 2015',
#    'entities': {'hashtags': [{'indices': [99, 112], 'text': 'BlackHat2015'}],
#     'media': [{'display_url': 'pic.twitter.com/cekFsQabp4',
#       'expanded_url': 'http://twitter.com/TeriRnNY/status/628980863015981057/photo/1',
#       'id': 628980822620643328,
#       'id_str': '628980822620643328',
#       'indices': [113, 135],
#       'media_url': 'http://pbs.twimg.com/media/CLqWucbWIAAmuZf.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/CLqWucbWIAAmuZf.jpg',
#       'sizes': {'large': {'h': 1024, 'resize': 'fit', 'w': 576},
#        'medium': {'h': 1024, 'resize': 'fit', 'w': 576},
#        'small': {'h': 604, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 628980863015981057,
#       'source_status_id_str': '628980863015981057',
#       'source_user_id': 16213949,
#       'source_user_id_str': '16213949',
#       'type': 'photo',
#       'url': 'http://t.co/cekFsQabp4'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 16213949,
#       'id_str': '16213949',
#       'indices': [3, 12],
#       'name': 'TeriRnNY',
#       'screen_name': 'TeriRnNY'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 629103306070212609,
#    'id_str': '629103306070212609',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 4,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Aug 05 17:28:18 +0000 2015',
#     'entities': {'hashtags': [{'indices': [85, 98], 'text': 'BlackHat2015'}],
#      'media': [{'display_url': 'pic.twitter.com/cekFsQabp4',
#        'expanded_url': 'http://twitter.com/TeriRnNY/status/628980863015981057/photo/1',
#        'id': 628980822620643328,
#        'id_str': '628980822620643328',
#        'indices': [99, 121],
#        'media_url': 'http://pbs.twimg.com/media/CLqWucbWIAAmuZf.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/CLqWucbWIAAmuZf.jpg',
#        'sizes': {'large': {'h': 1024, 'resize': 'fit', 'w': 576},
#         'medium': {'h': 1024, 'resize': 'fit', 'w': 576},
#         'small': {'h': 604, 'resize': 'fit', 'w': 340},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'http://t.co/cekFsQabp4'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 5,
#     'favorited': False,
#     'geo': None,
#     'id': 628980863015981057,
#     'id_str': '628980863015981057',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 4,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'FTC Commissioner Terrell McSweeny &amp; Ashkan Soltani technologists as policymakers #BlackHat2015 http://t.co/cekFsQabp4',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Sep 10 00:22:42 +0000 2008',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 8,
#      'follow_request_sent': False,
#      'followers_count': 75,
#      'following': False,
#      'friends_count': 519,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 16213949,
#      'id_str': '16213949',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 2,
#      'location': '',
#      'name': 'TeriRnNY',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16213949/1421026609',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/2667462996/9efe49e55e81c5c8b2b389df7e1d8675_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2667462996/9efe49e55e81c5c8b2b389df7e1d8675_normal.jpeg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'TeriRnNY',
#      'statuses_count': 295,
#      'time_zone': 'Quito',
#      'url': None,
#      'utc_offset': -18000,
#      'verified': False}},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M5)</a>',
#    'text': 'RT @TeriRnNY: FTC Commissioner Terrell McSweeny &amp; Ashkan Soltani technologists as policymakers #BlackHat2015 http://t.co/cekFsQabp4',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Feb 11 19:52:38 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Government communications director. Any opinions my own, RTs not endorsed.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 6,
#     'follow_request_sent': False,
#     'followers_count': 200,
#     'following': False,
#     'friends_count': 118,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 250777719,
#     'id_str': '250777719',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 10,
#     'location': '',
#     'name': 'Justin Cole',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/210952471/pr.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/210952471/pr.jpg',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/430147958483329024/qX5U5s9w_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/430147958483329024/qX5U5s9w_normal.png',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'CommsNews',
#     'statuses_count': 866,
#     'time_zone': None,
#     'url': None,
#     'utc_offset': None,
#     'verified': False}}]}

# %%
my_bot.auto_follow("#hackfest")
# Out:
# followed meistertask
# followed MaiaVisnovsky_
# followed spatialsource
# followed iRogue
# followed summeroftech
# followed BigPipeNZ
# followed mgratzer
# followed bulinutz
# followed RaphieBr
# followed mindmeister
# followed ohuebler
# followed sadayk
# followed Data_Vic
# followed DingoBusCharter
# followed Pearcey_org
# followed Aus3point0
# followed adrianporteous
# followed PublicSafetyNL
# followed ciscourbina
# followed sleepyDG777
# followed Transit_Hub
# followed VicRoads
# followed samjarman
# followed johnclegg
# followed Hossein_Parsa
# followed Mvandervlugt
# followed georabble
# followed thornedu
# followed Designer_Shae
# followed rlorenzo
# followed plaksina_lena
# followed marcel_dev_
# followed 4lexNZ
# followed thehackfest
# followed Marcus3467
# followed VicEngrGuy
# followed JulianWoodhouse
# followed Mistyepd
# followed ShockingBlanket
# followed shadrx_
# followed Cloud9IDE
# followed 1460kxno
# followed binary_koan
# followed lukesUbuntu
# followed TomReidy
# followed jaimejaime86
# followed ThomasMiddleto7
# followed lackingpears
# followed Psoda_Bruce
# followed PeterStoun
# followed Khorthok
# followed auto_matik55
# followed WarolG
# followed mogest
# followed DevTroy
# followed IndieGameDevBot
# followed abbaslums
# followed sanityinc
# followed newportandy
# followed MichaelJThorn
# followed ExcapeArtist
