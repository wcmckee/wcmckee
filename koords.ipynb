# %%
import koordinates

# %%
client = koordinates.Client(host='labs.koordinates.com', token='06e2dc0ee7304b6faf10b8e643a2e091')

# %%
for layer in client.layers.order_by('created_at')[:10]:
    print(layer)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/koordinates/client.py in _raw_request(self, method, url, headers, *args, **kwargs)
#     138             logger.debug('Response: headers=%s', r.headers)
# --> 139             r.raise_for_status()
#     140             return r
#
# /usr/lib/python3/dist-packages/requests/models.py in raise_for_status(self)
#     824         if http_error_msg:
# --> 825             raise HTTPError(http_error_msg, response=self)
#     826
#
# HTTPError: 401 Client Error: UNAUTHORIZED
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-30-d7087f279564> in <module>()
# ----> 1 for layer in client.layers.order_by('created_at')[:10]:
#       2     print(layer)
#
# ...

# %%
clcata = client.catalog

# %%
cli = clcata.list

# %%
cli
# Out:
# <bound method CatalogManager.list of <koordinates.catalog.CatalogManager object at 0xb192c270>>

# %%
clcata.get

# %%
for layer in client.layers.list():
    print(layer.id)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/koordinates/client.py in _raw_request(self, method, url, headers, *args, **kwargs)
#     138             logger.debug('Response: headers=%s', r.headers)
# --> 139             r.raise_for_status()
#     140             return r
#
# /usr/lib/python3/dist-packages/requests/models.py in raise_for_status(self)
#     824         if http_error_msg:
# --> 825             raise HTTPError(http_error_msg, response=self)
#     826
#
# HTTPError: 401 Client Error: UNAUTHORIZED
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-26-fefc95ea3b59> in <module>()
# ----> 1 for layer in client.layers.list():
#       2     print(layer.id)
#
# ...

# %%
opschoolzone = open('/home/wcm/Downloads/ccschool.csv', 'r')

# %%
rdsczone = opschoolzone.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-15ff8443a20f> in <module>()
# ----> 1 rdsczone = opschoolzone.read()
#
# /usr/lib/python3.4/encodings/ascii.py in decode(self, input, final)
#      24 class IncrementalDecoder(codecs.IncrementalDecoder):
#      25     def decode(self, input, final=False):
# ---> 26         return codecs.ascii_decode(input, self.errors)[0]
#      27
#      28 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe2 in position 2128: ordinal not in range(128)

# %%
import requests

# %%
for layer in client.layers.order_by('created_at')[:10]:
    print(layer)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/koordinates/client.py in _raw_request(self, method, url, headers, *args, **kwargs)
#     138             logger.debug('Response: headers=%s', r.headers)
# --> 139             r.raise_for_status()
#     140             return r
#
# /usr/lib/python3/dist-packages/requests/models.py in raise_for_status(self)
#     824         if http_error_msg:
# --> 825             raise HTTPError(http_error_msg, response=self)
#     826
#
# HTTPError: 401 Client Error: UNAUTHORIZED
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-25-d7087f279564> in <module>()
# ----> 1 for layer in client.layers.order_by('created_at')[:10]:
#       2     print(layer)
#
# ...

# %%
import pandas

# %%
schnam = pandas.read_csv('/home/wcm/Downloads/nzschoolzone.csv', index_col=2)

# %%
schnam.What.cal
# Out:
# SchoolName
# Palmerston North Intermediate     POLYGON ((2730615.392561290878803 6090740.2981...
# Freyberg High School              POLYGON ((2745043.800439903512597 6112272.2000...
# Mangorei School                   POLYGON ((2600820.374574344605207 6221545.9363...
# Henderson Intermediate            MULTIPOLYGON (((2655706.400050358846784 647910...
# Waitakere School                  POLYGON ((2638211.172554983757436 6481043.2694...
# Hutt Intermediate                 POLYGON ((2670071.899875052738935 5993800.9007...
# Tawa Intermediate                 POLYGON ((2665593.000167114194483 6001129.0004...
# Tawa College                      POLYGON ((2665593.000167114194483 6001129.0004...
# Long Bay College (Home Zone 1)    POLYGON ((2661280.464295980520546 6501402.4220...
# Long Bay College (Home Zone 2)    POLYGON ((2664664.430524981580675 6501501.9185...
# Clive School                      POLYGON ((2842612.622409 6171176.2446414381265...
# ...

# %%
schnam
# Out:
#                                                                                   ﻿WKT  \
# SchoolName
# Palmerston North Intermediate        POLYGON ((2730615.392561290878803 6090740.2981...
# Freyberg High School                 POLYGON ((2745043.800439903512597 6112272.2000...
# Mangorei School                      POLYGON ((2600820.374574344605207 6221545.9363...
# Henderson Intermediate               MULTIPOLYGON (((2655706.400050358846784 647910...
# Waitakere School                     POLYGON ((2638211.172554983757436 6481043.2694...
# Hutt Intermediate                    POLYGON ((2670071.899875052738935 5993800.9007...
# Tawa Intermediate                    POLYGON ((2665593.000167114194483 6001129.0004...
# Tawa College                         POLYGON ((2665593.000167114194483 6001129.0004...
# Long Bay College (Home Zone 1)       POLYGON ((2661280.464295980520546 6501402.4220...
# Long Bay College (Home Zone 2)       POLYGON ((2664664.430524981580675 6501501.9185...
# ...

# %%
schnam.SchoolID.keys()
# Out:
# Index(['Palmerston North Intermediate', 'Freyberg High School', 'Mangorei School', 'Henderson Intermediate', 'Waitakere School', 'Hutt Intermediate', 'Tawa Intermediate', 'Tawa College', 'Long Bay College (Home Zone 1)', 'Long Bay College (Home Zone 2)', 'Clive School', 'Paremata School', 'Fairfield School (Dunedin)', 'Riverdale School (P North)', 'Fernside School', 'Christchurch Girls' High School', 'Plimmerton School', 'Palmerston North Girls' High School', 'Frankley School', 'Allenton School', 'Rosebank School (Balclutha)', 'Riverlands School', 'Wellington Girls' College', 'Westburn School', 'Avonside Girls' High School', 'Beckenham School', 'Burnside High School', 'Hukanui School', 'Massey Primary School', 'Kerikeri High School', 'Mangere Bridge School', 'Waterlea Public School', 'Whakatane High School', 'Whenuapai School', 'Red Beach School', 'Tauranga Intermediate', 'Willowpark School', 'Pakuranga Intermediate', 'St Joseph's School (Queenstown)', 'Ngaere School', 'Fernridge Sch
# ...
